# %%
#import dependencies
import pandas as pd
import requests
import time
import json
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,inspect

# %% [markdown]
# # API Calls for 2020 Weeks 1-17 - Projected

# %%
#week 1
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/1?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
print(json.dumps(response[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010103",
#  "PlayerID": 19781,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-13T13:00:00",
#  "Week": 1,
#  "Team": "BAL",
#  "Opponent": "CLE",
#  "HomeOrAway": "HOME",
#  "Number": 8,
#  "Name": "Lamar Jackson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 22.4,
#  "PassingCompletions": 13.7,
#  "PassingYards": 165.7,
#  "PassingCompletionPercentage": 42.2,
#  "PassingYardsPerAttempt": 3.7,
#  "PassingYardsPerCompletion": 6.2,
#  "PassingTouchdowns": 1.0,
#  "PassingInterceptions": 0.4,
#  "PassingRating": 63.7,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 6.2,
#  "RushingYards": 42.0,
#  "RushingYardsPerAttempt": 2.5,
#  "RushingTouchdowns": 0.2,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk1_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk1_df
# Out:
# Empty DataFrame
# Columns: [Week, PlayerID, Name, Team, Position, Activated, Played, Started, FantasyPoints, FantasyPointsPPR, OpponentRank, OpponentPositionRank]
# Index: []

# %%
for i in range(0,len(response)):
    currentItem = response[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk1_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], response[i]["Name"],response[i]["Team"], response[i]["Position"], response[i]["Activated"], response[i]["Played"], response[i]["Started"], response[i]["FantasyPoints"], response[i]["FantasyPointsPPR"], response[i]["OpponentRank"], response[i]["OpponentPositionRank"]]

# %%
#week 1
wk1_df
# Out:
#     Week PlayerID                 Name Team Position Activated Played Started  \
# 0      1    19781        Lamar Jackson  BAL       QB         1      1       1
# 1      1    18890      Patrick Mahomes   KC       QB         1      1       1
# 2      1    18055         Dak Prescott  DAL       QB         1      1       1
# 3      1    14536       Russell Wilson  SEA       QB         1      1       1
# 4      1    18857       Deshaun Watson  HOU       QB         1      1       1
# ..   ...      ...                  ...  ...      ...       ...    ...     ...
# 799    1    22437            Jake Burt   NE       TE         0      0       0
# 800    1    22456        Chase Harrell   SF       TE         0      0       0
# 801    1    22458         Farrod Green  IND       TE         0      0       0
# 802    1    19961  Ray-Ray McCloud III  PIT       WR         1      1       1
# 803    1    19184          JoJo Natson  CLE       WR         1      1       1
#
# ...

# %%
#week2
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/2?key=4339cb9aa27441699f1883848f498899"
response_2 = requests.get(query_url).json()
print(json.dumps(response_2[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010213",
#  "PlayerID": 19781,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-20T16:25:00",
#  "Week": 2,
#  "Team": "BAL",
#  "Opponent": "HOU",
#  "HomeOrAway": "AWAY",
#  "Number": 8,
#  "Name": "Lamar Jackson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 20.5,
#  "PassingCompletions": 13.5,
#  "PassingYards": 155.5,
#  "PassingCompletionPercentage": 42.6,
#  "PassingYardsPerAttempt": 3.2,
#  "PassingYardsPerCompletion": 4.8,
#  "PassingTouchdowns": 0.8,
#  "PassingInterceptions": 0.3,
#  "PassingRating": 62.2,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 5.5,
#  "RushingYards": 40.5,
#  "RushingYardsPerAttempt": 2.0,
#  "RushingTouchdowns": 0.2,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk2_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk2_df 
for i in range(0,len(response_2)):
    currentItem = response_2[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk2_df.loc[i] = [response_2[i]["Week"],response_2[i]["PlayerID"], response_2[i]["Name"],response_2[i]["Team"], response_2[i]["Position"], response_2[i]["Activated"], response_2[i]["Played"], response_2[i]["Started"], response_2[i]["FantasyPoints"], response_2[i]["FantasyPointsPPR"], response_2[i]["OpponentRank"], response_2[i]["OpponentPositionRank"]]

# %%
wk2_df
# Out:
#     Week PlayerID                 Name Team Position Activated Played Started  \
# 0      2    19781        Lamar Jackson  BAL       QB         1      1       1
# 1      2    18890      Patrick Mahomes   KC       QB         1      1       1
# 2      2    18055         Dak Prescott  DAL       QB         1      1       1
# 3      2    19801           Josh Allen  BUF       QB         1      1       1
# 4      2    20889         Kyler Murray  ARI       QB         1      1       1
# ..   ...      ...                  ...  ...      ...       ...    ...     ...
# 813    2    22437            Jake Burt   NE       TE         0      0       0
# 814    2    22441      Nathan Cottrell  JAX       RB         1      1       1
# 815    2    22456        Chase Harrell   SF       TE         0      0       0
# 816    2    19961  Ray-Ray McCloud III  PIT       WR         1      1       1
# 817    2    19184          JoJo Natson  CLE       WR         1      1       1
#
# ...

# %%
#week 3 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/3?key=4339cb9aa27441699f1883848f498899"
response_3 = requests.get(query_url).json()
print(json.dumps(response_3[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010303",
#  "PlayerID": 19781,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-28T20:15:00",
#  "Week": 3,
#  "Team": "BAL",
#  "Opponent": "KC",
#  "HomeOrAway": "HOME",
#  "Number": 8,
#  "Name": "Lamar Jackson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 13.1,
#  "PassingCompletions": 3.7,
#  "PassingYards": 100.9,
#  "PassingCompletionPercentage": 28.4,
#  "PassingYardsPerAttempt": 1.3,
#  "PassingYardsPerCompletion": 1.9,
#  "PassingTouchdowns": 0.3,
#  "PassingInterceptions": 0.1,
#  "PassingRating": 40.9,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 2.3,
#  "RushingYards": 26.5,
#  "RushingYardsPerAttempt": 0.8,
#  "RushingTouchdowns": 0.1,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk3_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk3_df 
for i in range(0,len(response_3)):
    currentItem = response_3[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk3_df.loc[i] = [response_3[i]["Week"],response_3[i]["PlayerID"], response_3[i]["Name"],response_3[i]["Team"], response_3[i]["Position"], response_3[i]["Activated"], response_3[i]["Played"], response_3[i]["Started"], response_3[i]["FantasyPoints"], response_3[i]["FantasyPointsPPR"], response_3[i]["OpponentRank"], response_3[i]["OpponentPositionRank"]]

# %%
wk3_df
# Out:
#     Week PlayerID             Name Team Position Activated Played Started  \
# 0      3    19781    Lamar Jackson  BAL       QB         1      1       1
# 1      3    20889     Kyler Murray  ARI       QB         1      1       1
# 2      3    14536   Russell Wilson  SEA       QB         1      1       1
# 3      3    13320       Cam Newton   NE       QB         1      1       1
# 4      3    18890  Patrick Mahomes   KC       QB         1      1       1
# ..   ...      ...              ...  ...      ...       ...    ...     ...
# 830    3    22436     Rashod Berry   NE       TE         0      0       0
# 831    3    22437        Jake Burt   NE       TE         0      0       0
# 832    3    22441  Nathan Cottrell  JAX       RB         1      1       0
# 833    3    22456    Chase Harrell   SF       TE         0      0       0
# 834    3    22458     Farrod Green  IND       TE         1      1       0
#
#      FantasyPoints  FantasyPointsPPR OpponentRank OpponentPositionRank
# ...

# %%
#week 4 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/4?key=4339cb9aa27441699f1883848f498899"
response_4 = requests.get(query_url).json()
print(json.dumps(response_4[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010435",
#  "PlayerID": 19781,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-04T13:00:00",
#  "Week": 4,
#  "Team": "BAL",
#  "Opponent": "WAS",
#  "HomeOrAway": "AWAY",
#  "Number": 8,
#  "Name": "Lamar Jackson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 40.1,
#  "PassingCompletions": 24.1,
#  "PassingYards": 321.0,
#  "PassingCompletionPercentage": 79.6,
#  "PassingYardsPerAttempt": 10.7,
#  "PassingYardsPerCompletion": 17.8,
#  "PassingTouchdowns": 3.3,
#  "PassingInterceptions": 1.1,
#  "PassingRating": 124.8,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 17.9,
#  "RushingYards": 85.9,
#  "RushingYardsPerAttempt": 8.8,
#  "RushingTouchdowns": 0.7,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk4_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk4_df 
for i in range(0,len(response_4)):
    currentItem = response_4[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk4_df.loc[i] = [response_4[i]["Week"],response_4[i]["PlayerID"], response_4[i]["Name"],response_4[i]["Team"], response_4[i]["Position"], response_4[i]["Activated"], response_4[i]["Played"], response_4[i]["Started"], response_4[i]["FantasyPoints"], response_4[i]["FantasyPointsPPR"], response_4[i]["OpponentRank"], response_4[i]["OpponentPositionRank"]]

# %%
wk4_df
# Out:
#     Week PlayerID             Name Team Position Activated Played Started  \
# 0      4    19781    Lamar Jackson  BAL       QB         1      1       1
# 1      4    14536   Russell Wilson  SEA       QB         1      1       1
# 2      4    18890  Patrick Mahomes   KC       QB         1      1       1
# 3      4    19801       Josh Allen  BUF       QB         1      1       1
# 4      4    18055     Dak Prescott  DAL       QB         1      1       1
# ..   ...      ...              ...  ...      ...       ...    ...     ...
# 788    4    22437        Jake Burt   NE       TE         0      0       0
# 789    4    22441  Nathan Cottrell  JAX       RB         1      1       0
# 790    4    22456    Chase Harrell   SF       TE         0      0       0
# 791    4    22458     Farrod Green  IND       TE         1      1       0
# 792    4     5834       Matt Moore   KC       QB         1      1       1
#
#      FantasyPoints  FantasyPointsPPR OpponentRank OpponentPositionRank
# ...

# %%
#week 5 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/5?key=4339cb9aa27441699f1883848f498899"
response_5 = requests.get(query_url).json()
print(json.dumps(response_5[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010516",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-11T13:00:00",
#  "Week": 5,
#  "Team": "KC",
#  "Opponent": "LV",
#  "HomeOrAway": "HOME",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 55.1,
#  "PassingCompletions": 33.0,
#  "PassingYards": 440.5,
#  "PassingCompletionPercentage": 87.2,
#  "PassingYardsPerAttempt": 11.7,
#  "PassingYardsPerCompletion": 19.2,
#  "PassingTouchdowns": 5.6,
#  "PassingInterceptions": 1.0,
#  "PassingRating": 162.1,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 7.9,
#  "RushingYards": 29.8,
#  "RushingYardsPerAttempt": 10.8,
#  "RushingTouchdowns": 0.4,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk5_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk5_df 
for i in range(0,len(response_5)):
    currentItem = response_5[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk5_df.loc[i] = [response_5[i]["Week"],response_5[i]["PlayerID"], response_5[i]["Name"],response_5[i]["Team"], response_5[i]["Position"], response_5[i]["Activated"], response_5[i]["Played"], response_5[i]["Started"], response_5[i]["FantasyPoints"], response_5[i]["FantasyPointsPPR"], response_5[i]["OpponentRank"], response_5[i]["OpponentPositionRank"]]

# %%
wk5_df
# Out:
#     Week PlayerID                 Name Team Position Activated Played Started  \
# 0      5    18890      Patrick Mahomes   KC       QB         1      1       1
# 1      5    14536       Russell Wilson  SEA       QB         1      1       1
# 2      5    19781        Lamar Jackson  BAL       QB         1      1       1
# 3      5    18055         Dak Prescott  DAL       QB         1      1       1
# 4      5    19801           Josh Allen  BUF       QB         1      1       1
# ..   ...      ...                  ...  ...      ...       ...    ...     ...
# 729    5    22433           John Hurst   TB       WR         1      1       1
# 730    5    22441      Nathan Cottrell  JAX       RB         1      1       0
# 731    5    22456        Chase Harrell   SF       TE         0      0       0
# 732    5    22458         Farrod Green  IND       TE         1      1       0
# 733    5    19961  Ray-Ray McCloud III  PIT       WR         1      1       1
#
# ...

# %%
#week 6 

query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/6?key=4339cb9aa27441699f1883848f498899"
response_6 = requests.get(query_url).json()
print(json.dumps(response_6[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010604",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-19T17:00:00",
#  "Week": 6,
#  "Team": "KC",
#  "Opponent": "BUF",
#  "HomeOrAway": "AWAY",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 42.1,
#  "PassingCompletions": 28.8,
#  "PassingYards": 346.5,
#  "PassingCompletionPercentage": 76.7,
#  "PassingYardsPerAttempt": 10.2,
#  "PassingYardsPerCompletion": 13.3,
#  "PassingTouchdowns": 2.9,
#  "PassingInterceptions": 0.8,
#  "PassingRating": 111.6,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 6.0,
#  "RushingYards": 27.4,
#  "RushingYardsPerAttempt": 6.0,
#  "RushingTouchdowns": 0.3,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk6_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk6_df 
for i in range(0,len(response_6)):
    currentItem = response_6[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk6_df.loc[i] = [response_6[i]["Week"],response_6[i]["PlayerID"], response_6[i]["Name"],response_6[i]["Team"], response_6[i]["Position"], response_6[i]["Activated"], response_6[i]["Played"], response_6[i]["Started"], response_6[i]["FantasyPoints"], response_6[i]["FantasyPointsPPR"], response_6[i]["OpponentRank"], response_6[i]["OpponentPositionRank"]]

# %%
wk6_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0      6    18890   Patrick Mahomes   KC       QB         1      1       1
# 1      6    20889      Kyler Murray  ARI       QB         1      1       1
# 2      6    19781     Lamar Jackson  BAL       QB         1      1       1
# 3      6    19801        Josh Allen  BUF       QB         1      1       1
# 4      6    18857    Deshaun Watson  HOU       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 732    6    22441   Nathan Cottrell  JAX       RB         1      1       0
# 733    6    22456     Chase Harrell   SF       TE         0      0       0
# 734    6    22458      Farrod Green  IND       TE         1      1       0
# 735    6    22477  Dominique Dafney   GB       TE         0      0       0
# 736    6    22482   Sergio Castillo  NYJ        K         0      0       0
#
# ...

# %%
#week 7 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/7?key=4339cb9aa27441699f1883848f498899"
response_7 = requests.get(query_url).json()
print(json.dumps(response_7[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010701",
#  "PlayerID": 14536,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-25T20:20:00",
#  "Week": 7,
#  "Team": "SEA",
#  "Opponent": "ARI",
#  "HomeOrAway": "AWAY",
#  "Number": 3,
#  "Name": "Russell Wilson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 61.5,
#  "PassingCompletions": 41.2,
#  "PassingYards": 512.2,
#  "PassingCompletionPercentage": 119.2,
#  "PassingYardsPerAttempt": 14.6,
#  "PassingYardsPerCompletion": 21.4,
#  "PassingTouchdowns": 7.9,
#  "PassingInterceptions": 1.5,
#  "PassingRating": 213.6,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 14.5,
#  "RushingYards": 41.2,
#  "RushingYardsPerAttempt": 14.5,
#  "RushingTouchdowns": 0.6,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk7_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk7_df 
for i in range(0,len(response_7)):
    currentItem = response_7[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk7_df.loc[i] = [response_7[i]["Week"],response_7[i]["PlayerID"], response_7[i]["Name"],response_7[i]["Team"], response_7[i]["Position"], response_7[i]["Activated"], response_7[i]["Played"], response_7[i]["Started"], response_7[i]["FantasyPoints"], response_7[i]["FantasyPointsPPR"], response_7[i]["OpponentRank"], response_7[i]["OpponentPositionRank"]]

# %%
wk7_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0      7    14536    Russell Wilson  SEA       QB         1      1       1
# 1      7    20889      Kyler Murray  ARI       QB         1      1       1
# 2      7    18890   Patrick Mahomes   KC       QB         1      1       1
# 3      7    18857    Deshaun Watson  HOU       QB         1      1       1
# 4      7    19801        Josh Allen  BUF       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 734    7    22441   Nathan Cottrell  JAX       RB         1      1       0
# 735    7    22456     Chase Harrell   SF       TE         0      0       0
# 736    7    22477  Dominique Dafney   GB       TE         0      0       0
# 737    7    22482   Sergio Castillo  NYJ        K         0      0       0
# 738    7    23101      Parker Hesse  TEN       TE         0      0       0
#
# ...

# %%
#week 8
 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/8?key=4339cb9aa27441699f1883848f498899"
response_8 = requests.get(query_url).json()
print(json.dumps(response_8[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010816",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-01T13:00:00",
#  "Week": 8,
#  "Team": "KC",
#  "Opponent": "NYJ",
#  "HomeOrAway": "HOME",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 16.6,
#  "PassingCompletions": 4.4,
#  "PassingYards": 132.9,
#  "PassingCompletionPercentage": 26.5,
#  "PassingYardsPerAttempt": 1.6,
#  "PassingYardsPerCompletion": 2.7,
#  "PassingTouchdowns": 0.5,
#  "PassingInterceptions": 0.1,
#  "PassingRating": 46.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 0.9,
#  "RushingYards": 10.4,
#  "RushingYardsPerAttempt": 0.9,
#  "RushingTouchdowns": 0.1,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk8_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk8_df 
for i in range(0,len(response_8)):
    currentItem = response_8[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk8_df.loc[i] = [response_8[i]["Week"],response_8[i]["PlayerID"], response_8[i]["Name"],response_8[i]["Team"], response_8[i]["Position"], response_8[i]["Activated"], response_8[i]["Played"], response_8[i]["Started"], response_8[i]["FantasyPoints"], response_8[i]["FantasyPointsPPR"], response_8[i]["OpponentRank"], response_8[i]["OpponentPositionRank"]]

# %%
wk8_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0      8    18890   Patrick Mahomes   KC       QB         1      1       1
# 1      8    14536    Russell Wilson  SEA       QB         1      1       1
# 2      8    19781     Lamar Jackson  BAL       QB         1      1       1
# 3      8     2593     Aaron Rodgers   GB       QB         1      1       1
# 4      8    19801        Josh Allen  BUF       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 733    8    22458      Farrod Green  IND       TE         1      1       0
# 734    8    22477  Dominique Dafney   GB       TE         0      0       0
# 735    8    22482   Sergio Castillo  NYJ        K         0      0       0
# 736    8    23101      Parker Hesse  TEN       TE         0      0       0
# 737    8    11565     Andre Roberts  BUF       WR         1      1       1
#
# ...

# %%
#week 9 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/9?key=4339cb9aa27441699f1883848f498899"
response_9 = requests.get(query_url).json()
print(json.dumps(response_9[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010904",
#  "PlayerID": 14536,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-08T13:00:00",
#  "Week": 9,
#  "Team": "SEA",
#  "Opponent": "BUF",
#  "HomeOrAway": "AWAY",
#  "Number": 3,
#  "Name": "Russell Wilson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 33.1,
#  "PassingCompletions": 19.9,
#  "PassingYards": 265.2,
#  "PassingCompletionPercentage": 55.9,
#  "PassingYardsPerAttempt": 6.8,
#  "PassingYardsPerCompletion": 12.1,
#  "PassingTouchdowns": 1.9,
#  "PassingInterceptions": 0.5,
#  "PassingRating": 85.6,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 4.7,
#  "RushingYards": 27.9,
#  "RushingYardsPerAttempt": 4.2,
#  "RushingTouchdowns": 0.2,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk9_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk9_df 
for i in range(0,len(response_9)):
    currentItem = response_9[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk9_df.loc[i] = [response_9[i]["Week"],response_9[i]["PlayerID"], response_9[i]["Name"],response_9[i]["Team"], response_9[i]["Position"], response_9[i]["Activated"], response_9[i]["Played"], response_9[i]["Started"], response_9[i]["FantasyPoints"], response_9[i]["FantasyPointsPPR"], response_9[i]["OpponentRank"], response_9[i]["OpponentPositionRank"]]

# %%
wk9_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0      9    14536    Russell Wilson  SEA       QB         1      1       1
# 1      9    20889      Kyler Murray  ARI       QB         1      1       1
# 2      9    18890   Patrick Mahomes   KC       QB         1      1       1
# 3      9    18857    Deshaun Watson  HOU       QB         1      1       1
# 4      9    19801        Josh Allen  BUF       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 735    9    22458      Farrod Green  IND       TE         1      1       0
# 736    9    22477  Dominique Dafney   GB       TE         0      0       0
# 737    9    23101      Parker Hesse  TEN       TE         0      0       0
# 738    9    18973     C.J. Beathard   SF       QB         1      1       1
# 739    9    19854      Dante Pettis  NYG       WR         1      1       1
#
# ...

# %%
#week 10 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/10?key=4339cb9aa27441699f1883848f498899"
response_10 = requests.get(query_url).json()
print(json.dumps(response_10[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011001",
#  "PlayerID": 20889,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-15T16:05:00",
#  "Week": 10,
#  "Team": "ARI",
#  "Opponent": "BUF",
#  "HomeOrAway": "HOME",
#  "Number": 1,
#  "Name": "Kyler Murray",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 57.1,
#  "PassingCompletions": 40.0,
#  "PassingYards": 431.5,
#  "PassingCompletionPercentage": 109.9,
#  "PassingYardsPerAttempt": 12.0,
#  "PassingYardsPerCompletion": 17.3,
#  "PassingTouchdowns": 4.8,
#  "PassingInterceptions": 2.3,
#  "PassingRating": 155.9,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 16.5,
#  "RushingYards": 79.2,
#  "RushingYardsPerAttempt": 12.5,
#  "RushingTouchdowns": 1.3,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk10_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk10_df 
for i in range(0,len(response_10)):
    currentItem = response_10[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk10_df.loc[i] = [response_10[i]["Week"],response_10[i]["PlayerID"], response_10[i]["Name"],response_10[i]["Team"], response_10[i]["Position"], response_10[i]["Activated"], response_10[i]["Played"], response_10[i]["Started"], response_10[i]["FantasyPoints"], response_10[i]["FantasyPointsPPR"], response_10[i]["OpponentRank"], response_10[i]["OpponentPositionRank"]]

# %%
wk10_df
# Out:
#     Week PlayerID               Name Team Position Activated Played Started  \
# 0     10    20889       Kyler Murray  ARI       QB         1      1       1
# 1     10    19801         Josh Allen  BUF       QB         1      1       1
# 2     10    14536     Russell Wilson  SEA       QB         1      1       1
# 3     10    19781      Lamar Jackson  BAL       QB         1      1       1
# 4     10     2593      Aaron Rodgers   GB       QB         1      1       1
# ..   ...      ...                ...  ...      ...       ...    ...     ...
# 742   10    22456      Chase Harrell   SF       TE         0      0       0
# 743   10    22458       Farrod Green  IND       TE         1      1       0
# 744   10    22475  Paul Quessenberry   NE       TE         0      0       0
# 745   10    22477   Dominique Dafney   GB       TE         0      0       0
# 746   10    23101       Parker Hesse  TEN       TE         0      0       0
#
# ...

# %%
#week 11 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/11?key=4339cb9aa27441699f1883848f498899"
response_11 = requests.get(query_url).json()
print(json.dumps(response_11[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011130",
#  "PlayerID": 20889,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-19T20:20:00",
#  "Week": 11,
#  "Team": "ARI",
#  "Opponent": "SEA",
#  "HomeOrAway": "AWAY",
#  "Number": 1,
#  "Name": "Kyler Murray",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 29.5,
#  "PassingCompletions": 19.7,
#  "PassingYards": 228.6,
#  "PassingCompletionPercentage": 54.0,
#  "PassingYardsPerAttempt": 4.9,
#  "PassingYardsPerCompletion": 7.3,
#  "PassingTouchdowns": 1.1,
#  "PassingInterceptions": 0.6,
#  "PassingRating": 77.8,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 5.0,
#  "RushingYards": 38.7,
#  "RushingYardsPerAttempt": 3.8,
#  "RushingTouchdowns": 0.3,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk11_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk11_df 
for i in range(0,len(response_11)):
    currentItem = response_11[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk11_df.loc[i] = [response_11[i]["Week"],response_11[i]["PlayerID"], response_11[i]["Name"],response_11[i]["Team"], response_11[i]["Position"], response_11[i]["Activated"], response_11[i]["Played"], response_11[i]["Started"], response_11[i]["FantasyPoints"], response_11[i]["FantasyPointsPPR"], response_11[i]["OpponentRank"], response_11[i]["OpponentPositionRank"]]

# %%
wk11_df
# Out:
#     Week PlayerID               Name Team Position Activated Played Started  \
# 0     11    20889       Kyler Murray  ARI       QB         1      1       1
# 1     11    14536     Russell Wilson  SEA       QB         1      1       1
# 2     11    18890    Patrick Mahomes   KC       QB         1      1       1
# 3     11    19781      Lamar Jackson  BAL       QB         1      1       1
# 4     11    21681     Justin Herbert  LAC       QB         1      1       1
# ..   ...      ...                ...  ...      ...       ...    ...     ...
# 739   11    22458       Farrod Green  IND       TE         1      1       0
# 740   11    22473       Connor Davis  NYJ       TE         0      0       0
# 741   11    22475  Paul Quessenberry   NE       TE         0      0       0
# 742   11    22477   Dominique Dafney   GB       TE         0      0       0
# 743   11    23101       Parker Hesse  TEN       TE         0      0       0
#
# ...

# %%
#week  12

query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/12?key=4339cb9aa27441699f1883848f498899"
response_12 = requests.get(query_url).json()
print(json.dumps(response_12[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011233",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-29T16:25:00",
#  "Week": 12,
#  "Team": "KC",
#  "Opponent": "TB",
#  "HomeOrAway": "AWAY",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 59.7,
#  "PassingCompletions": 35.8,
#  "PassingYards": 477.8,
#  "PassingCompletionPercentage": 93.2,
#  "PassingYardsPerAttempt": 12.3,
#  "PassingYardsPerCompletion": 19.9,
#  "PassingTouchdowns": 5.3,
#  "PassingInterceptions": 1.1,
#  "PassingRating": 157.8,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 9.0,
#  "RushingYards": 28.2,
#  "RushingYardsPerAttempt": 11.0,
#  "RushingTouchdowns": 0.5,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk12_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk12_df 
for i in range(0,len(response_12)):
    currentItem = response_12[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk12_df.loc[i] = [response_12[i]["Week"],response_12[i]["PlayerID"], response_12[i]["Name"],response_12[i]["Team"], response_12[i]["Position"], response_12[i]["Activated"], response_12[i]["Played"], response_12[i]["Started"], response_12[i]["FantasyPoints"], response_12[i]["FantasyPointsPPR"], response_12[i]["OpponentRank"], response_12[i]["OpponentPositionRank"]]

# %%
wk12_df
# Out:
#     Week PlayerID               Name Team Position Activated Played Started  \
# 0     12    18890    Patrick Mahomes   KC       QB         1      1       1
# 1     12    20889       Kyler Murray  ARI       QB         1      1       1
# 2     12    18857     Deshaun Watson  HOU       QB         1      1       1
# 3     12    19801         Josh Allen  BUF       QB         1      1       1
# 4     12    14536     Russell Wilson  SEA       QB         1      1       1
# ..   ...      ...                ...  ...      ...       ...    ...     ...
# 861   12    22458       Farrod Green  IND       TE         1      1       0
# 862   12    22473       Connor Davis  NYJ       TE         0      0       0
# 863   12    22475  Paul Quessenberry   NE       TE         0      0       0
# 864   12    22477   Dominique Dafney   GB       TE         0      0       0
# 865   12    23101       Parker Hesse  TEN       TE         0      0       0
#
# ...

# %%
#week 13 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/13?key=4339cb9aa27441699f1883848f498899"
response_13 = requests.get(query_url).json()
print(json.dumps(response_13[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011316",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-06T20:20:00",
#  "Week": 13,
#  "Team": "KC",
#  "Opponent": "DEN",
#  "HomeOrAway": "HOME",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 27.9,
#  "PassingCompletions": 16.8,
#  "PassingYards": 223.4,
#  "PassingCompletionPercentage": 44.3,
#  "PassingYardsPerAttempt": 4.3,
#  "PassingYardsPerCompletion": 7.1,
#  "PassingTouchdowns": 1.3,
#  "PassingInterceptions": 0.3,
#  "PassingRating": 75.8,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 2.1,
#  "RushingYards": 15.8,
#  "RushingYardsPerAttempt": 2.9,
#  "RushingTouchdowns": 0.1,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk13_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk13_df 
for i in range(0,len(response_13)):
    currentItem = response_13[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk13_df.loc[i] = [response_13[i]["Week"],response_13[i]["PlayerID"], response_13[i]["Name"],response_13[i]["Team"], response_13[i]["Position"], response_13[i]["Activated"], response_13[i]["Played"], response_13[i]["Started"], response_13[i]["FantasyPoints"], response_13[i]["FantasyPointsPPR"], response_13[i]["OpponentRank"], response_13[i]["OpponentPositionRank"]]

# %%
wk13_df
# Out:
#     Week PlayerID               Name Team Position Activated Played Started  \
# 0     13    18890    Patrick Mahomes   KC       QB         1      1       1
# 1     13    14536     Russell Wilson  SEA       QB         1      1       1
# 2     13     2593      Aaron Rodgers   GB       QB         1      1       1
# 3     13    20889       Kyler Murray  ARI       QB         1      1       1
# 4     13    21681     Justin Herbert  LAC       QB         1      1       1
# ..   ...      ...                ...  ...      ...       ...    ...     ...
# 802   13    22458       Farrod Green  IND       TE         1      1       0
# 803   13    22473       Connor Davis  NYJ       TE         0      0       0
# 804   13    22475  Paul Quessenberry   NE       TE         0      0       0
# 805   13    22477   Dominique Dafney   GB       TE         0      0       0
# 806   13    23101       Parker Hesse  TEN       TE         0      0       0
#
# ...

# %%
#week 14 

query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/14?key=4339cb9aa27441699f1883848f498899"
response_14 = requests.get(query_url).json()
print(json.dumps(response_14[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011419",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-13T13:00:00",
#  "Week": 14,
#  "Team": "KC",
#  "Opponent": "MIA",
#  "HomeOrAway": "AWAY",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 65.5,
#  "PassingCompletions": 45.5,
#  "PassingYards": 541.0,
#  "PassingCompletionPercentage": 117.5,
#  "PassingYardsPerAttempt": 14.3,
#  "PassingYardsPerCompletion": 20.8,
#  "PassingTouchdowns": 6.8,
#  "PassingInterceptions": 1.8,
#  "PassingRating": 172.2,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 11.5,
#  "RushingYards": 38.5,
#  "RushingYardsPerAttempt": 16.2,
#  "RushingTouchdowns": 0.6,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk14_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk14_df 
for i in range(0,len(response_14)):
    currentItem = response_14[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk14_df.loc[i] = [response_14[i]["Week"],response_14[i]["PlayerID"], response_14[i]["Name"],response_14[i]["Team"], response_14[i]["Position"], response_14[i]["Activated"], response_14[i]["Played"], response_14[i]["Started"], response_14[i]["FantasyPoints"], response_14[i]["FantasyPointsPPR"], response_14[i]["OpponentRank"], response_14[i]["OpponentPositionRank"]]

# %%
wk14_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0     14    18890   Patrick Mahomes   KC       QB         1      1       1
# 1     14    14536    Russell Wilson  SEA       QB         1      1       1
# 2     14     2593     Aaron Rodgers   GB       QB         1      1       1
# 3     14    21681    Justin Herbert  LAC       QB         1      1       1
# 4     14    20889      Kyler Murray  ARI       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 864   14    22477  Dominique Dafney   GB       TE         0      0       0
# 865   14    22485  Taylor Russolino  DEN        K         0      0       0
# 866   14    23101      Parker Hesse  TEN       TE         0      0       0
# 867   14    11565     Andre Roberts  BUF       WR         1      1       1
# 868   14    21295    Nsimba Webster  LAR       WR         1      1       1
#
# ...

# %%
#week 15 

query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/15?key=4339cb9aa27441699f1883848f498899"
response_15 = requests.get(query_url).json()
print(json.dumps(response_15[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011522",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-20T16:25:00",
#  "Week": 15,
#  "Team": "KC",
#  "Opponent": "NO",
#  "HomeOrAway": "AWAY",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 36.5,
#  "PassingCompletions": 24.8,
#  "PassingYards": 294.3,
#  "PassingCompletionPercentage": 62.3,
#  "PassingYardsPerAttempt": 7.1,
#  "PassingYardsPerCompletion": 11.3,
#  "PassingTouchdowns": 2.0,
#  "PassingInterceptions": 0.6,
#  "PassingRating": 91.3,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 3.5,
#  "RushingYards": 18.1,
#  "RushingYardsPerAttempt": 4.2,
#  "RushingTouchdowns": 0.2,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk15_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk15_df 
for i in range(0,len(response_15)):
    currentItem = response_15[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk15_df.loc[i] = [response_15[i]["Week"],response_15[i]["PlayerID"], response_15[i]["Name"],response_15[i]["Team"], response_15[i]["Position"], response_15[i]["Activated"], response_15[i]["Played"], response_15[i]["Started"], response_15[i]["FantasyPoints"], response_15[i]["FantasyPointsPPR"], response_15[i]["OpponentRank"], response_15[i]["OpponentPositionRank"]]

# %%
wk15_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0     15    18890   Patrick Mahomes   KC       QB         1      1       1
# 1     15    19781     Lamar Jackson  BAL       QB         1      1       1
# 2     15     2593     Aaron Rodgers   GB       QB         1      1       1
# 3     15    20889      Kyler Murray  ARI       QB         1      1       1
# 4     15    19801        Josh Allen  BUF       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 865   15    22477  Dominique Dafney   GB       TE         0      0       0
# 866   15    22485  Taylor Russolino  DEN        K         0      0       0
# 867   15    23101      Parker Hesse  TEN       TE         0      0       0
# 868   15      611        Joe Flacco  NYJ       QB         1      1       1
# 869   15    21295    Nsimba Webster  LAR       WR         1      1       1
#
# ...

# %%
#week 16 

query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/16?key=4339cb9aa27441699f1883848f498899"
response_16 = requests.get(query_url).json()
print(json.dumps(response_16[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011616",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-27T13:00:00",
#  "Week": 16,
#  "Team": "KC",
#  "Opponent": "ATL",
#  "HomeOrAway": "HOME",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 69.5,
#  "PassingCompletions": 41.7,
#  "PassingYards": 555.9,
#  "PassingCompletionPercentage": 98.2,
#  "PassingYardsPerAttempt": 13.2,
#  "PassingYardsPerCompletion": 22.3,
#  "PassingTouchdowns": 6.8,
#  "PassingInterceptions": 1.6,
#  "PassingRating": 150.3,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 10.9,
#  "RushingYards": 33.5,
#  "RushingYardsPerAttempt": 13.6,
#  "RushingTouchdowns": 0.5,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
#week 16 
wk16_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk16_df 
for i in range(0,len(response_16)):
    currentItem = response_16[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk16_df.loc[i] = [response_16[i]["Week"],response_16[i]["PlayerID"], response_16[i]["Name"],response_16[i]["Team"], response_16[i]["Position"], response_16[i]["Activated"], response_16[i]["Played"], response_16[i]["Started"], response_16[i]["FantasyPoints"], response_16[i]["FantasyPointsPPR"], response_16[i]["OpponentRank"], response_16[i]["OpponentPositionRank"]]

# %%
wk16_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0     16    18890   Patrick Mahomes   KC       QB         1      1       1
# 1     16    20889      Kyler Murray  ARI       QB         1      1       1
# 2     16     2593     Aaron Rodgers   GB       QB         1      1       1
# 3     16    19781     Lamar Jackson  BAL       QB         1      1       1
# 4     16    18857    Deshaun Watson  HOU       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 877   16    22485  Taylor Russolino  DEN        K         0      0       0
# 878   16    23101      Parker Hesse  TEN       TE         0      0       0
# 879   16    11565     Andre Roberts  BUF       WR         1      1       1
# 880   16    16850      Sean Mannion  MIN       QB         1      1       1
# 881   16    21295    Nsimba Webster  LAR       WR         1      1       1
#
# ...

# %%
#week17 
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/17?key=4339cb9aa27441699f1883848f498899"
response_17 = requests.get(query_url).json()
print(json.dumps(response_17[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011707",
#  "PlayerID": 19781,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2021-01-03T13:00:00",
#  "Week": 17,
#  "Team": "BAL",
#  "Opponent": "CIN",
#  "HomeOrAway": "AWAY",
#  "Number": 8,
#  "Name": "Lamar Jackson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 24.3,
#  "PassingCompletions": 16.1,
#  "PassingYards": 198.1,
#  "PassingCompletionPercentage": 58.9,
#  "PassingYardsPerAttempt": 6.1,
#  "PassingYardsPerCompletion": 10.4,
#  "PassingTouchdowns": 1.4,
#  "PassingInterceptions": 0.5,
#  "PassingRating": 88.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 12.1,
#  "RushingYards": 58.2,
#  "RushingYardsPerAttempt": 3.6,
#  "RushingTouchdowns": 0.3,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk17_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk17_df 
for i in range(0,len(response_17)):
    currentItem = response_17[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk17_df.loc[i] = [response_17[i]["Week"],response_17[i]["PlayerID"], response_17[i]["Name"],response_17[i]["Team"], response_17[i]["Position"], response_17[i]["Activated"], response_17[i]["Played"], response_17[i]["Started"], response_17[i]["FantasyPoints"], response_17[i]["FantasyPointsPPR"], response_17[i]["OpponentRank"], response_17[i]["OpponentPositionRank"]]

# %%
wk17_df
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0     17    19781     Lamar Jackson  BAL       QB         1      1       1
# 1     17    18857    Deshaun Watson  HOU       QB         1      1       1
# 2     17     2593     Aaron Rodgers   GB       QB         1      1       1
# 3     17    13799    Ryan Tannehill  TEN       QB         1      1       1
# 4     17     4314         Tom Brady   TB       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 876   17    22482   Sergio Castillo  NYJ        K         1      1       0
# 877   17    22485  Taylor Russolino  DEN        K         0      0       0
# 878   17    23101      Parker Hesse  TEN       TE         0      0       0
# 879   17    21295    Nsimba Webster  LAR       WR         1      1       1
# 880   17    19763        Josh Rosen   SF       QB         1      1       1
#
# ...

# %%
#Join using concatenation
frames= [wk1_df,wk2_df,wk3_df,wk4_df,wk5_df,wk6_df,wk7_df,wk8_df,wk9_df,wk10_df,wk11_df,wk12_df,wk13_df,wk14_df,wk15_df,wk16_df,wk17_df]
proj2020 = pd.concat(frames)
# proj2020.head()
proj2020
# Out:
#     Week PlayerID              Name Team Position Activated Played Started  \
# 0      1    19781     Lamar Jackson  BAL       QB         1      1       1
# 1      1    18890   Patrick Mahomes   KC       QB         1      1       1
# 2      1    18055      Dak Prescott  DAL       QB         1      1       1
# 3      1    14536    Russell Wilson  SEA       QB         1      1       1
# 4      1    18857    Deshaun Watson  HOU       QB         1      1       1
# ..   ...      ...               ...  ...      ...       ...    ...     ...
# 876   17    22482   Sergio Castillo  NYJ        K         1      1       0
# 877   17    22485  Taylor Russolino  DEN        K         0      0       0
# 878   17    23101      Parker Hesse  TEN       TE         0      0       0
# 879   17    21295    Nsimba Webster  LAR       WR         1      1       1
# 880   17    19763        Josh Rosen   SF       QB         1      1       1
#
# ...

# %%
proj2020.to_csv('2020_DATA_TBG.csv', index = False)

# %%
print(len(proj2020))
# Out:
# 13604

# %%
#read in Strength of Schedule CSV data from weeks 1-5 of partial 2021 season
df = pd.read_csv("SOS.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-c0740dc92f64> in <module>
#       1 #read in Strength of Schedule CSV data from weeks 1-5 of partial 2021 season
# ----> 2 df = pd.read_csv("SOS.csv")
#       3 df
#
# ...

# %% [markdown]
# ## 2020 actual data

# %%
# week 1  

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/1?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
print(json.dumps(response_1a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010105",
#  "PlayerID": 20824,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-13T13:00:00",
#  "Week": 1,
#  "Team": "LV",
#  "Opponent": "CAR",
#  "HomeOrAway": "AWAY",
#  "Number": 28,
#  "Name": "Josh Jacobs",
#  "Position": "RB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 35.6,
#  "RushingYards": 132.4,
#  "RushingYardsPerAttempt": 7.5,
#  "RushingTouchdowns": 6.1,
#  "RushingLong": 19.9,
#  "ReceivingTargets": 12.2,
#  "Receptions": 8.1,
#  "ReceivingYards": 65.5,
#  "ReceivingYardsPerReception": 16.4,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk1act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk1act_df 
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk1act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["PlayerID"], response_1a[i]["Name"],response_1a[i]["Team"], response_1a[i]["Position"], response_1a[i]["Activated"], response_1a[i]["Played"], response_1a[i]["Started"], response_1a[i]["FantasyPoints"], response_1a[i]["FantasyPointsPPR"], response_1a[i]["OpponentRank"], response_1a[i]["OpponentPositionRank"]]

# %%
wk1act_df
# Out:
#      Week PlayerID             Name Team Position Activated Played Started  \
# 0       1    20824      Josh Jacobs   LV       RB         1      1       1
# 1       1    14536   Russell Wilson  SEA       QB         1      1       1
# 2       1     2593    Aaron Rodgers   GB       QB         1      1       1
# 3       1    19801       Josh Allen  BUF       QB         1      1       1
# 4       1    16470    Davante Adams   GB       WR         1      1       1
# ...   ...      ...              ...  ...      ...       ...    ...     ...
# 1804    1    18019     Nick Vannett  DEN       TE         1      1       0
# 1805    1    19209   Patrick Ricard  BAL       FB         1      1       1
# 1806    1    18467  Sharrod Neasman  ATL       FS         1      1       0
# 1807    1    20748     Mike Edwards   TB       FS         1      1       0
# 1808    1    21279     Jamie Gillan  CLE        P         1      1       0
#
# ...

# %%
#week2 
# week 1  

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/2?key=3b5fde40e15048148341780099372fc3"
response_2a = requests.get(query_url).json()
print(json.dumps(response_2a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010212",
#  "PlayerID": 19045,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-20T13:00:00",
#  "Week": 2,
#  "Team": "GB",
#  "Opponent": "DET",
#  "HomeOrAway": "HOME",
#  "Number": 33,
#  "Name": "Aaron Jones",
#  "Position": "RB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 18.2,
#  "RushingYards": 170.0,
#  "RushingYardsPerAttempt": 9.5,
#  "RushingTouchdowns": 2.0,
#  "RushingLong": 75.9,
#  "ReceivingTargets": 8.2,
#  "Receptions": 4.1,
#  "ReceivingYards": 68.8,
#  "ReceivingYardsPerReception": 17.2,
#  "ReceivingTouchdowns": 1.0,
# ...

# %%
#week2 
wk2act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk2act_df 
for i in range(0,len(response_2a)):
    currentItem = response_2a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk2act_df.loc[i] = [response_2a[i]["Week"],response_2a[i]["PlayerID"], response_2a[i]["Name"],response_2a[i]["Team"], response_2a[i]["Position"], response_2a[i]["Activated"], response_2a[i]["Played"], response_2a[i]["Started"], response_2a[i]["FantasyPoints"], response_2a[i]["FantasyPointsPPR"], response_2a[i]["OpponentRank"], response_2a[i]["OpponentPositionRank"]]

# %%
wk2act_df
# Out:
#      Week PlayerID             Name Team Position Activated Played Started  \
# 0       2    19045      Aaron Jones   GB       RB         1      1       1
# 1       2    18055     Dak Prescott  DAL       QB         1      1       1
# 2       2    13320       Cam Newton   NE       QB         1      1       1
# 3       2    19801       Josh Allen  BUF       QB         1      1       1
# 4       2    14536   Russell Wilson  SEA       QB         1      1       1
# ...   ...      ...              ...  ...      ...       ...    ...     ...
# 1810    2    21837      J.J. Taylor   NE       RB         1      1       0
# 1811    2    19937      Keke Coutee  HOU       WR         1      1       0
# 1812    2    20859        Drew Lock  DEN       QB         1      1       1
# 1813    2    14252     Kirk Cousins  MIN       QB         1      1       1
# 1814    2    20950  Benny Snell Jr.  PIT       RB         1      1       0
#
# ...

# %%
#week3  
# week 1  

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/3?key=3b5fde40e15048148341780099372fc3"
response_3a = requests.get(query_url).json()
print(json.dumps(response_3a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010303",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-28T20:15:00",
#  "Week": 3,
#  "Team": "KC",
#  "Opponent": "BAL",
#  "HomeOrAway": "AWAY",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 47.3,
#  "PassingCompletions": 34.9,
#  "PassingYards": 433.9,
#  "PassingCompletionPercentage": 83.2,
#  "PassingYardsPerAttempt": 10.4,
#  "PassingYardsPerCompletion": 14.0,
#  "PassingTouchdowns": 5.1,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 150.5,
#  "PassingLong": 55.2,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 5.1,
#  "RushingYards": 29.3,
#  "RushingYardsPerAttempt": 8.3,
#  "RushingTouchdowns": 1.3,
#  "RushingLong": 13.5,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk3act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk3act_df 
for i in range(0,len(response_3a)):
    currentItem = response_3a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk3act_df.loc[i] = [response_3a[i]["Week"],response_3a[i]["PlayerID"], response_3a[i]["Name"],response_3a[i]["Team"], response_3a[i]["Position"], response_3a[i]["Activated"], response_3a[i]["Played"], response_3a[i]["Started"], response_3a[i]["FantasyPoints"], response_3a[i]["FantasyPointsPPR"], response_3a[i]["OpponentRank"], response_3a[i]["OpponentPositionRank"]]

# %%
wk3act_df
# Out:
#      Week PlayerID              Name Team Position Activated Played Started  \
# 0       3    18890   Patrick Mahomes   KC       QB         1      1       1
# 1       3    14536    Russell Wilson  SEA       QB         1      1       1
# 2       3    18878      Alvin Kamara   NO       RB         1      1       0
# 3       3    19801        Josh Allen  BUF       QB         1      1       0
# 4       3    16830     Tyler Lockett  SEA       WR         1      1       1
# ...   ...      ...               ...  ...      ...       ...    ...     ...
# 1805    3    22295  Tershawn Wharton   KC       DT         1      1       0
# 1806    3    22300    Tommy Townsend   KC        P         1      1       0
# 1807    3    20912      Tony Pollard  DAL       RB         1      1       0
# 1808    3    20964   Darwin Thompson   KC       RB         1      1       0
# 1809    3    19238       Taysom Hill   NO       QB         1      1       1
#
# ...

# %%
#week4 


query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/4?key=3b5fde40e15048148341780099372fc3"
response_4a = requests.get(query_url).json()
print(json.dumps(response_4a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010409",
#  "PlayerID": 18055,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-04T13:00:00",
#  "Week": 4,
#  "Team": "DAL",
#  "Opponent": "CLE",
#  "HomeOrAway": "HOME",
#  "Number": 4,
#  "Name": "Dak Prescott",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 19.4,
#  "PassingCompletions": 13.7,
#  "PassingYards": 168.2,
#  "PassingCompletionPercentage": 23.7,
#  "PassingYardsPerAttempt": 1.0,
#  "PassingYardsPerCompletion": 1.4,
#  "PassingTouchdowns": 0.4,
#  "PassingInterceptions": 0.1,
#  "PassingRating": 37.8,
#  "PassingLong": 14.4,
#  "PassingSacks": 0.3,
#  "PassingSackYards": 2.4,
#  "RushingAttempts": 0.2,
#  "RushingYards": 1.3,
#  "RushingYardsPerAttempt": 0.7,
#  "RushingTouchdowns": 0.0,
#  "RushingLong": 1.2,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk4act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk4act_df 
for i in range(0,len(response_4a)):
    currentItem = response_4a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk4act_df.loc[i] = [response_4a[i]["Week"],response_4a[i]["PlayerID"], response_4a[i]["Name"],response_4a[i]["Team"], response_4a[i]["Position"], response_4a[i]["Activated"], response_4a[i]["Played"], response_4a[i]["Started"], response_4a[i]["FantasyPoints"], response_4a[i]["FantasyPointsPPR"], response_4a[i]["OpponentRank"], response_4a[i]["OpponentPositionRank"]]

# %%
wk4act_df
# Out:
#      Week PlayerID                Name Team Position Activated Played Started  \
# 0       4    18055        Dak Prescott  DAL       QB         1      1       1
# 1       4    18858           Joe Mixon  CIN       RB         1      1       1
# 2       4    16389   Odell Beckham Jr.  CLE       WR         1      1       1
# 3       4     4314           Tom Brady   TB       QB         1      1       1
# 4       4     2593       Aaron Rodgers   GB       QB         1      1       1
# ...   ...      ...                 ...  ...      ...       ...    ...     ...
# 1700    4    18067       Jordan Howard  MIA       RB         1      1       0
# 1701    4    20283           Tim Boyle   GB       QB         1      1       0
# 1702    4    21842  Adrian Killins Jr.  PHI       RB         1      1       0
# 1703    4    14257  Robert Griffin III  BAL       QB         1      1       0
# 1704    4    17218      DeAndre Carter  HOU       WR         1      1       0
#
# ...

# %%
#week5 


query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/5?key=3b5fde40e15048148341780099372fc3"
response_5a = requests.get(query_url).json()
print(json.dumps(response_5a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010528",
#  "PlayerID": 21752,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-11T13:00:00",
#  "Week": 5,
#  "Team": "PIT",
#  "Opponent": "PHI",
#  "HomeOrAway": "HOME",
#  "Number": 11,
#  "Name": "Chase Claypool",
#  "Position": "WR",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 1.6,
#  "RushingYards": 3.2,
#  "RushingYardsPerAttempt": 1.1,
#  "RushingTouchdowns": 0.5,
#  "RushingLong": 1.6,
#  "ReceivingTargets": 5.8,
#  "Receptions": 3.7,
#  "ReceivingYards": 80.1,
#  "ReceivingYardsPerReception": 11.4,
#  "ReceivingTouchdowns": 1.6,
# ...

# %%
wk5act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk5act_df 
for i in range(0,len(response_5a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk5act_df.loc[i] = [response_5a[i]["Week"],response_5a[i]["PlayerID"], response_5a[i]["Name"],response_5a[i]["Team"], response_5a[i]["Position"], response_5a[i]["Activated"], response_5a[i]["Played"], response_1a[i]["Started"], response_5a[i]["FantasyPoints"], response_5a[i]["FantasyPointsPPR"], response_5a[i]["OpponentRank"], response_5a[i]["OpponentPositionRank"]]

# %%
wk5act_df
# Out:
#      Week PlayerID              Name Team Position Activated Played Started  \
# 0       5    21752    Chase Claypool  PIT       WR         1      1       1
# 1       5    13799    Ryan Tannehill  TEN       QB         1      1       1
# 2       5    18890   Patrick Mahomes   KC       QB         1      1       1
# 3       5     8283  Ryan Fitzpatrick  MIA       QB         1      1       1
# 4       5    21681    Justin Herbert  LAC       QB         1      1       1
# ...   ...      ...               ...  ...      ...       ...    ...     ...
# 1590    5    11565     Andre Roberts  BUF       WR         1      1       0
# 1591    5    18103  Jakeem Grant Sr.  MIA       WR         1      1       0
# 1592    5    16041   Jimmy Garoppolo   SF       QB         1      1       0
# 1593    5    18445       Mike Thomas  CIN       WR         1      1       0
# 1594    5    21788   Ke'Shawn Vaughn   TB       RB         1      1       0
#
# ...

# %%
#week6 

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/6?key=3b5fde40e15048148341780099372fc3"
response_6a = requests.get(query_url).json()
print(json.dumps(response_6a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010634",
#  "PlayerID": 17959,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-18T13:00:00",
#  "Week": 6,
#  "Team": "TEN",
#  "Opponent": "HOU",
#  "HomeOrAway": "HOME",
#  "Number": 22,
#  "Name": "Derrick Henry",
#  "Position": "RB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 25.1,
#  "RushingYards": 241.5,
#  "RushingYardsPerAttempt": 10.9,
#  "RushingTouchdowns": 2.6,
#  "RushingLong": 107.1,
#  "ReceivingTargets": 6.5,
#  "Receptions": 2.6,
#  "ReceivingYards": 59.2,
#  "ReceivingYardsPerReception": 29.6,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk6act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk6act_df 
for i in range(0,len(response_6a)):
    currentItem = response_6a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]
    wk6act_df.loc[i] = [response_6a[i]["Week"],response_6a[i]["PlayerID"], response_6a[i]["Name"],response_6a[i]["Team"], response_6a[i]["Position"], response_6a[i]["Activated"], response_6a[i]["Played"], response_6a[i]["Started"], response_6a[i]["FantasyPoints"], response_6a[i]["FantasyPointsPPR"], response_6a[i]["OpponentRank"], response_6a[i]["OpponentPositionRank"]]

# %%
wk6act_df
# Out:
#      Week PlayerID                Name Team Position Activated Played Started  \
# 0       6    17959       Derrick Henry  TEN       RB         1      1       1
# 1       6    18857      Deshaun Watson  HOU       QB         1      1       1
# 2       6      732           Matt Ryan  ATL       QB         1      1       1
# 3       6    21685    Justin Jefferson  MIN       WR         1      1       1
# 4       6    17920        Carson Wentz  PHI       QB         1      1       1
# ...   ...      ...                 ...  ...      ...       ...    ...     ...
# 1607    6    22087  Reggie Robinson II  DAL       CB         0      0       0
# 1608    6    22146         Ben DiNucci  DAL       QB         1      1       0
# 1609    6    22233        Rashad Smith  DAL       LB         0      0       0
# 1610    6    19850       Mason Rudolph  PIT       QB         1      1       0
# 1611    6    19979      Jordan Wilkins  IND       RB         1      1       0
#
# ...

# %%
#week7  
query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/7?key=3b5fde40e15048148341780099372fc3"
response_7a = requests.get(query_url).json()
print(json.dumps(response_7a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010729",
#  "PlayerID": 21681,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-25T16:25:00",
#  "Week": 7,
#  "Team": "LAC",
#  "Opponent": "JAX",
#  "HomeOrAway": "HOME",
#  "Number": 10,
#  "Name": "Justin Herbert",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 44.0,
#  "PassingCompletions": 27.6,
#  "PassingYards": 355.3,
#  "PassingCompletionPercentage": 64.3,
#  "PassingYardsPerAttempt": 8.5,
#  "PassingYardsPerCompletion": 13.2,
#  "PassingTouchdowns": 3.1,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 114.0,
#  "PassingLong": 71.7,
#  "PassingSacks": 1.0,
#  "PassingSackYards": 2.1,
#  "RushingAttempts": 9.4,
#  "RushingYards": 67.6,
#  "RushingYardsPerAttempt": 7.7,
#  "RushingTouchdowns": 1.0,
#  "RushingLong": 31.7,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk7act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk7act_df 
for i in range(0,len(response_7a)):
    currentItem = response_7a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk7act_df.loc[i] = [response_7a[i]["Week"],response_7a[i]["PlayerID"], response_7a[i]["Name"],response_7a[i]["Team"], response_7a[i]["Position"], response_7a[i]["Activated"], response_7a[i]["Played"], response_7a[i]["Started"], response_7a[i]["FantasyPoints"], response_7a[i]["FantasyPointsPPR"], response_7a[i]["OpponentRank"], response_7a[i]["OpponentPositionRank"]]

# %%
wk7act_df
# Out:
#      Week PlayerID             Name Team Position Activated Played Started  \
# 0       7    21681   Justin Herbert  LAC       QB         1      1       1
# 1       7    16830    Tyler Lockett  SEA       WR         1      1       1
# 2       7    20889     Kyler Murray  ARI       QB         1      1       1
# 3       7     4314        Tom Brady   TB       QB         1      1       1
# 4       7    21693       Joe Burrow  CIN       QB         1      1       1
# ...   ...      ...              ...  ...      ...       ...    ...     ...
# 1606    7    20283        Tim Boyle   GB       QB         1      1       0
# 1607    7    16510  Jerick McKinnon   SF       RB         1      1       0
# 1608    7    13320       Cam Newton   NE       QB         1      1       1
# 1609    7    21752   Chase Claypool  PIT       WR         1      1       1
# 1610    7    18992   Dede Westbrook  JAX       WR         1      1       0
#
# ...

# %%
#week8 
query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/8?key=3b5fde40e15048148341780099372fc3"
response_8a = requests.get(query_url).json()
print(json.dumps(response_8a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010812",
#  "PlayerID": 18872,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-01T13:00:00",
#  "Week": 8,
#  "Team": "MIN",
#  "Opponent": "GB",
#  "HomeOrAway": "AWAY",
#  "Number": 33,
#  "Name": "Dalvin Cook",
#  "Position": "RB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 3.0,
#  "RushingYards": 51.5,
#  "RushingYardsPerAttempt": 0.5,
#  "RushingTouchdowns": 0.3,
#  "RushingLong": 11.7,
#  "ReceivingTargets": 0.3,
#  "Receptions": 0.2,
#  "ReceivingYards": 19.9,
#  "ReceivingYardsPerReception": 3.1,
#  "ReceivingTouchdowns": 0.1,
# ...

# %%
wk8act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk8act_df 
for i in range(0,len(response_8a)):
    currentItem = response_8a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk8act_df.loc[i] = [response_8a[i]["Week"],response_8a[i]["PlayerID"], response_8a[i]["Name"],response_8a[i]["Team"], response_8a[i]["Position"], response_8a[i]["Activated"], response_8a[i]["Played"], response_8a[i]["Started"], response_8a[i]["FantasyPoints"], response_8a[i]["FantasyPointsPPR"], response_8a[i]["OpponentRank"], response_8a[i]["OpponentPositionRank"]]

# %%
wk8act_df
# Out:
#      Week PlayerID             Name Team Position Activated Played Started  \
# 0       8    18872      Dalvin Cook  MIN       RB         1      1       1
# 1       8    18890  Patrick Mahomes   KC       QB         1      1       1
# 2       8    14536   Russell Wilson  SEA       QB         1      1       1
# 3       8    20875       DK Metcalf  SEA       WR         1      1       1
# 4       8    20646  Robert Spillane  PIT      ILB         1      1       1
# ...   ...      ...              ...  ...      ...       ...    ...     ...
# 1616    8    22070     Khalil Davis   TB       DL         0      0       0
# 1617    8    22429         Cam Gill   TB       LB         1      1       0
# 1618    8    20013   Cedrick Wilson  DAL       WR         1      1       0
# 1619    8    19947    Chris Herndon  NYJ       TE         1      1       1
# 1620    8    19854     Dante Pettis   SF       WR         1      1       0
#
# ...

# %%
 #week9  
query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/9?key=3b5fde40e15048148341780099372fc3"
response_9a = requests.get(query_url).json()
print(json.dumps(response_9a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202010901",
#  "PlayerID": 20889,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-08T16:25:00",
#  "Week": 9,
#  "Team": "ARI",
#  "Opponent": "MIA",
#  "HomeOrAway": "HOME",
#  "Number": 1,
#  "Name": "Kyler Murray",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 27.1,
#  "PassingCompletions": 21.9,
#  "PassingYards": 295.5,
#  "PassingCompletionPercentage": 84.4,
#  "PassingYardsPerAttempt": 11.4,
#  "PassingYardsPerCompletion": 14.1,
#  "PassingTouchdowns": 3.3,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 157.1,
#  "PassingLong": 58.5,
#  "PassingSacks": 1.1,
#  "PassingSackYards": 19.8,
#  "RushingAttempts": 11.5,
#  "RushingYards": 110.7,
#  "RushingYardsPerAttempt": 10.0,
#  "RushingTouchdowns": 1.1,
#  "RushingLong": 29.2,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
wk9act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk9act_df 
for i in range(0,len(response_9a)):
    currentItem = response_9a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk9act_df.loc[i] = [response_9a[i]["Week"],response_9a[i]["PlayerID"], response_9a[i]["Name"],response_9a[i]["Team"], response_9a[i]["Position"], response_9a[i]["Activated"], response_9a[i]["Played"], response_9a[i]["Started"], response_9a[i]["FantasyPoints"], response_9a[i]["FantasyPointsPPR"], response_9a[i]["OpponentRank"], response_9a[i]["OpponentPositionRank"]]

# %%
wk9act_df
# Out:
#      Week PlayerID                  Name Team Position Activated Played  \
# 0       9    20889          Kyler Murray  ARI       QB         1      1
# 1       9    18872           Dalvin Cook  MIN       RB         1      1
# 2       9    19801            Josh Allen  BUF       QB         1      1
# 3       9    18890       Patrick Mahomes   KC       QB         1      1
# 4       9    20859             Drew Lock  DEN       QB         1      1
# ...   ...      ...                   ...  ...      ...       ...    ...
# 1631    9    21721        Devin Duvernay  BAL       WR         1      1
# 1632    9    21697  Laviska Shenault Jr.  JAX       WR         1      1
# 1633    9    12982        Blaine Gabbert   TB       QB         1      1
# 1634    9    16878            Blake Bell  DAL       TE         1      1
# 1635    9    21758         K.J. Hill Jr.  LAC       WR         1      1
#
#      Started  FantasyPoints  FantasyPointsPPR OpponentRank  \
# ...

# %%
 #week10 
 
query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/10?key=3b5fde40e15048148341780099372fc3"
response_10a = requests.get(query_url).json()
print(json.dumps(response_10a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011005",
#  "PlayerID": 4314,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-15T13:00:00",
#  "Week": 10,
#  "Team": "TB",
#  "Opponent": "CAR",
#  "HomeOrAway": "AWAY",
#  "Number": 12,
#  "Name": "Tom Brady",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 58.9,
#  "PassingCompletions": 42.3,
#  "PassingYards": 515.3,
#  "PassingCompletionPercentage": 108.5,
#  "PassingYardsPerAttempt": 13.1,
#  "PassingYardsPerCompletion": 18.4,
#  "PassingTouchdowns": 6.8,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 187.3,
#  "PassingLong": 66.5,
#  "PassingSacks": 2.3,
#  "PassingSackYards": 10.6,
#  "RushingAttempts": 4.6,
#  "RushingYards": 4.6,
#  "RushingYardsPerAttempt": 2.3,
#  "RushingTouchdowns": 2.3,
#  "RushingLong": 2.3,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk10act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk10act_df 
for i in range(0,len(response_10a)):
    currentItem = response_10a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk10act_df.loc[i] = [response_10a[i]["Week"],response_10a[i]["PlayerID"], response_10a[i]["Name"],response_10a[i]["Team"], response_10a[i]["Position"], response_10a[i]["Activated"], response_10a[i]["Played"], response_10a[i]["Started"], response_10a[i]["FantasyPoints"], response_10a[i]["FantasyPointsPPR"], response_10a[i]["OpponentRank"], response_10a[i]["OpponentPositionRank"]]

# %%
wk10act_df
# Out:
#      Week PlayerID                Name Team Position Activated Played Started  \
# 0      10     4314           Tom Brady   TB       QB         1      1       1
# 1      10    20889        Kyler Murray  ARI       QB         1      1       1
# 2      10     3807  Ben Roethlisberger  PIT       QB         1      1       1
# 3      10    18878        Alvin Kamara   NO       RB         1      1       0
# 4      10    19801          Josh Allen  BUF       QB         1      1       1
# ...   ...      ...                 ...  ...      ...       ...    ...     ...
# 1616   10    17965        C.J. Prosise  HOU       RB         1      1       0
# 1617   10    19072          Alex Armah  CAR       FB         1      1       0
# 1618   10    18137          Ted Karras  MIA        C         1      1       1
# 1619   10    18197       Alex Erickson  CIN       WR         1      1       0
# 1620   10    13117       Dwayne Harris  CHI       WR         1      1       0
#
# ...

# %%
#week11 

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/11?key=3b5fde40e15048148341780099372fc3"
response_11a = requests.get(query_url).json()
print(json.dumps(response_11a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011113",
#  "PlayerID": 18857,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-22T13:00:00",
#  "Week": 11,
#  "Team": "HOU",
#  "Opponent": "NE",
#  "HomeOrAway": "HOME",
#  "Number": 4,
#  "Name": "Deshaun Watson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 26.9,
#  "PassingCompletions": 20.4,
#  "PassingYards": 250.1,
#  "PassingCompletionPercentage": 55.0,
#  "PassingYardsPerAttempt": 4.9,
#  "PassingYardsPerCompletion": 6.5,
#  "PassingTouchdowns": 1.1,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 88.6,
#  "PassingLong": 32.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 3.2,
#  "RushingYards": 26.2,
#  "RushingYardsPerAttempt": 3.2,
#  "RushingTouchdowns": 0.5,
#  "RushingLong": 5.8,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk11act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk11act_df 
for i in range(0,len(response_11a)):
    currentItem = response_11a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk11act_df.loc[i] = [response_11a[i]["Week"],response_11a[i]["PlayerID"], response_11a[i]["Name"],response_11a[i]["Team"], response_11a[i]["Position"], response_11a[i]["Activated"], response_11a[i]["Played"], response_11a[i]["Started"], response_1a[i]["FantasyPoints"], response_11a[i]["FantasyPointsPPR"], response_11a[i]["OpponentRank"], response_11a[i]["OpponentPositionRank"]]

# %%
wk11act_df
# Out:
#      Week PlayerID              Name Team Position Activated Played Started  \
# 0      11    18857    Deshaun Watson  HOU       QB         1      1       1
# 1      11    21681    Justin Herbert  LAC       QB         1      1       1
# 2      11    15534      Adam Thielen  MIN       WR         1      1       1
# 3      11    19238       Taysom Hill   NO       QB         1      1       1
# 4      11    17922        Jared Goff  LAR       QB         1      1       0
# ...   ...      ...               ...  ...      ...       ...    ...     ...
# 1630   11    18900       Mo Alie-Cox  IND       TE         1      1       1
# 1631   11    21814        Jake Luton  JAX       QB         1      1       1
# 1632   11    19845      Frank Ragnow  DET        C         1      1       1
# 1633   11    21513  Darrius Shepherd   GB       WR         1      1       0
# 1634   11    17118           Ty Long  LAC        K         1      1       0
#
# ...

# %%
#week12 

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/12?key=3b5fde40e15048148341780099372fc3"
response_12a = requests.get(query_url).json()
print(json.dumps(response_12a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011233",
#  "PlayerID": 18082,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-11-29T16:25:00",
#  "Week": 12,
#  "Team": "KC",
#  "Opponent": "TB",
#  "HomeOrAway": "AWAY",
#  "Number": 10,
#  "Name": "Tyreek Hill",
#  "Position": "WR",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 0.0,
#  "RushingYards": 0.0,
#  "RushingYardsPerAttempt": 0.0,
#  "RushingTouchdowns": 0.0,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 21.7,
#  "Receptions": 18.8,
#  "ReceivingYards": 388.4,
#  "ReceivingYardsPerReception": 29.9,
#  "ReceivingTouchdowns": 6.3,
# ...

# %%
wk12act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk12act_df 
for i in range(0,len(response_12a)):
    currentItem = response_12a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk12act_df.loc[i] = [response_12a[i]["Week"],response_12a[i]["PlayerID"], response_12a[i]["Name"],response_12a[i]["Team"], response_12a[i]["Position"], response_12a[i]["Activated"], response_12a[i]["Played"], response_12a[i]["Started"], response_12a[i]["FantasyPoints"], response_12a[i]["FantasyPointsPPR"], response_12a[i]["OpponentRank"], response_12a[i]["OpponentPositionRank"]]

# %%
wk12act_df
# Out:
#      Week PlayerID                   Name Team Position Activated Played  \
# 0      12    18082            Tyreek Hill   KC       WR         1      1
# 1      12    17959          Derrick Henry  TEN       RB         1      1
# 2      12    18857         Deshaun Watson  HOU       QB         1      1
# 3      12    21921           Jeremy Chinn  CAR        S         1      1
# 4      12    21861         Antonio Gibson  WAS       RB         1      1
# ...   ...      ...                    ...  ...      ...       ...    ...
# 1874   12    21759            K.J. Hamler  DEN       WR         1      1
# 1875   12    21211          Patrick Laird  MIA       RB         1      1
# 1876   12    19961    Ray-Ray McCloud III  PIT       WR         1      1
# 1877   12    21997  Lloyd Cushenberry III  DEN       OL         1      1
# 1878   12    22213         Kendall Hinton  DEN       QB         1      1
#
#      Started  FantasyPoints  FantasyPointsPPR OpponentRank  \
# ...

# %%
#week13 

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/13?key=3b5fde40e15048148341780099372fc3"
response_13a = requests.get(query_url).json()
print(json.dumps(response_13a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011324",
#  "PlayerID": 16964,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-06T13:00:00",
#  "Week": 13,
#  "Team": "LV",
#  "Opponent": "NYJ",
#  "HomeOrAway": "AWAY",
#  "Number": 83,
#  "Name": "Darren Waller",
#  "Position": "TE",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 0.0,
#  "RushingYards": 0.0,
#  "RushingYardsPerAttempt": 0.0,
#  "RushingTouchdowns": 0.0,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 11.2,
#  "Receptions": 5.7,
#  "ReceivingYards": 132.0,
#  "ReceivingYardsPerReception": 10.2,
#  "ReceivingTouchdowns": 0.9,
# ...

# %%
wk13act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk13act_df 
for i in range(0,len(response_13a)):
    currentItem = response_13a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk13act_df.loc[i] = [response_13a[i]["Week"],response_13a[i]["PlayerID"], response_13a[i]["Name"],response_13a[i]["Team"], response_13a[i]["Position"], response_13a[i]["Activated"], response_13a[i]["Played"], response_13a[i]["Started"], response_13a[i]["FantasyPoints"], response_13a[i]["FantasyPointsPPR"], response_13a[i]["OpponentRank"], response_13a[i]["OpponentPositionRank"]]

# %%
wk13act_df
# Out:
#      Week PlayerID                      Name Team Position Activated Played  \
# 0      13    16964             Darren Waller   LV       TE         1      1
# 1      13    16311                Derek Carr   LV       QB         1      1
# 2      13    19801                Josh Allen  BUF       QB         1      1
# 3      13    19790            Baker Mayfield  CLE       QB         1      1
# 4      13    13799            Ryan Tannehill  TEN       QB         1      1
# ...   ...      ...                       ...  ...      ...       ...    ...
# 1731   13    20759               Ryan Finley  CIN       QB         1      1
# 1732   13    19976  Marquez Valdes-Scantling   GB       WR         1      1
# 1733   13    16837              Chris Conley  JAX       WR         1      1
# 1734   13    16834             Tevin Coleman   SF       RB         1      1
# 1735   13    21295            Nsimba Webster  LAR       WR         1      1
#
# ...

# %%
#week14 

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/14?key=3b5fde40e15048148341780099372fc3"
response_14a = requests.get(query_url).json()
print(json.dumps(response_14a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011423",
#  "PlayerID": 18909,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-13T13:00:00",
#  "Week": 14,
#  "Team": "ARI",
#  "Opponent": "NYG",
#  "HomeOrAway": "AWAY",
#  "Number": 43,
#  "Name": "Haason Reddick",
#  "Position": "OLB",
#  "PositionCategory": "DEF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 0.0,
#  "RushingYards": 0.0,
#  "RushingYardsPerAttempt": 0.0,
#  "RushingTouchdowns": 0.0,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk14act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk14act_df 
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk14act_df.loc[i] = [response_14a[i]["Week"],response_14a[i]["PlayerID"], response_14a[i]["Name"],response_14a[i]["Team"], response_14a[i]["Position"], response_14a[i]["Activated"], response_14a[i]["Played"], response_14a[i]["Started"], response_14a[i]["FantasyPoints"], response_14a[i]["FantasyPointsPPR"], response_14a[i]["OpponentRank"], response_14a[i]["OpponentPositionRank"]]

# %%
wk14act_df
# Out:
#      Week PlayerID             Name Team Position Activated Played Started  \
# 0      14    18909   Haason Reddick  ARI      OLB         1      1       1
# 1      14    19781    Lamar Jackson  BAL       QB         1      1       1
# 2      14    17959    Derrick Henry  TEN       RB         1      1       1
# 3      14     2593    Aaron Rodgers   GB       QB         1      1       1
# 4      14    19790   Baker Mayfield  CLE       QB         1      1       1
# ...   ...      ...              ...  ...      ...       ...    ...     ...
# 1804   14    22132     Kevin Dotson  PIT       OL         1      1       0
# 1805   14      430         Sam Koch  BAL        P         1      1       0
# 1806   14     3942  Tramon Williams  BAL       CB         0      0       0
# 1807   14     8459      Andre Smith  BAL       OT         0      0       0
# 1808   14    11008       Morgan Cox  BAL       LS         1      1       0
#
# ...

# %%
#week15 

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/15?key=3b5fde40e15048148341780099372fc3"
response_15a = requests.get(query_url).json()
print(json.dumps(response_15a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011501",
#  "PlayerID": 21831,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-20T16:05:00",
#  "Week": 15,
#  "Team": "PHI",
#  "Opponent": "ARI",
#  "HomeOrAway": "AWAY",
#  "Number": 2,
#  "Name": "Jalen Hurts",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 26.1,
#  "PassingCompletions": 14.2,
#  "PassingYards": 200.4,
#  "PassingCompletionPercentage": 32.3,
#  "PassingYardsPerAttempt": 2.7,
#  "PassingYardsPerCompletion": 5.0,
#  "PassingTouchdowns": 1.1,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 60.6,
#  "PassingLong": 24.9,
#  "PassingSacks": 2.1,
#  "PassingSackYards": 19.6,
#  "RushingAttempts": 3.9,
#  "RushingYards": 37.4,
#  "RushingYardsPerAttempt": 2.0,
#  "RushingTouchdowns": 0.4,
#  "RushingLong": 10.1,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk15act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk15act_df 
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk15act_df.loc[i] = [response_15a[i]["Week"],response_15a[i]["PlayerID"], response_15a[i]["Name"],response_15a[i]["Team"], response_15a[i]["Position"], response_15a[i]["Activated"], response_15a[i]["Played"], response_15a[i]["Started"], response_15a[i]["FantasyPoints"], response_15a[i]["FantasyPointsPPR"], response_15a[i]["OpponentRank"], response_15a[i]["OpponentPositionRank"]]

# %%
wk15act_df
# Out:
#      Week PlayerID             Name Team Position Activated Played Started  \
# 0      15    21831      Jalen Hurts  PHI       QB         1      1       1
# 1      15    19801       Josh Allen  BUF       QB         1      1       1
# 2      15    13799   Ryan Tannehill  TEN       QB         1      1       1
# 3      15    20889     Kyler Murray  ARI       QB         1      1       1
# 4      15    19781    Lamar Jackson  BAL       QB         1      1       1
# ...   ...      ...              ...  ...      ...       ...    ...     ...
# 1804   15    22091      Kyle Murphy  NYG       OL         0      0       0
# 1805   15    22150       TJ Brunson  NYG       LB         0      0       0
# 1806   15    22172  Jarren Williams  NYG       CB         1      1       0
# 1807   15     8433      Kevin Huber  CIN        P         1      1       0
# 1808   15    12330     Clark Harris  CIN       LS         1      1       0
#
# ...

# %%
#week16 


query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/16?key=3b5fde40e15048148341780099372fc3"
response_16a = requests.get(query_url).json()
print(json.dumps(response_16a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011622",
#  "PlayerID": 18878,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-12-25T16:30:00",
#  "Week": 16,
#  "Team": "NO",
#  "Opponent": "MIN",
#  "HomeOrAway": "HOME",
#  "Number": 41,
#  "Name": "Alvin Kamara",
#  "Position": "RB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 28.8,
#  "RushingYards": 202.9,
#  "RushingYardsPerAttempt": 12.0,
#  "RushingTouchdowns": 10.3,
#  "RushingLong": 52.4,
#  "ReceivingTargets": 8.6,
#  "Receptions": 5.1,
#  "ReceivingYards": 22.3,
#  "ReceivingYardsPerReception": 9.8,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk16act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk16act_df 
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk16act_df.loc[i] = [response_16a[i]["Week"],response_16a[i]["PlayerID"], response_16a[i]["Name"],response_16a[i]["Team"], response_1a[i]["Position"], response_16a[i]["Activated"], response_16a[i]["Played"], response_16a[i]["Started"], response_16a[i]["FantasyPoints"], response_16a[i]["FantasyPointsPPR"], response_16a[i]["OpponentRank"], response_16a[i]["OpponentPositionRank"]]

# %%
wk16act_df
# Out:
#      Week PlayerID              Name Team Position Activated Played Started  \
# 0      16    18878      Alvin Kamara   NO       RB         1      1       1
# 1      16    16906      Stefon Diggs  BUF       QB         1      1       1
# 2      16    19801        Josh Allen  BUF       QB         1      1       1
# 3      16    16470     Davante Adams   GB       QB         1      1       1
# 4      16    16597        Mike Evans   TB       WR         1      1       1
# ...   ...      ...               ...  ...      ...       ...    ...     ...
# 1804   16    20384       Joshua Kalu  TEN       TE         1      1       0
# 1805   16    21060        Nate Davis  TEN       FB         1      1       1
# 1806   16    21310  Khari Blasingame  TEN       FS         1      1       0
# 1807   16    21360   Derick Roberson  TEN       FS         0      0       0
# 1808   16    21581        Kareem Orr  TEN        P         0      0       0
#
# ...

# %%
#week17 


query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/17?key=3b5fde40e15048148341780099372fc3"
response_17a = requests.get(query_url).json()
print(json.dumps(response_17a[0],indent=1))
# print(denselist[:100])
# Out:
# {
#  "GameKey": "202011721",
#  "PlayerID": 13320,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2021-01-03T13:00:00",
#  "Week": 17,
#  "Team": "NE",
#  "Opponent": "NYJ",
#  "HomeOrAway": "HOME",
#  "Number": 1,
#  "Name": "Cam Newton",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 15.8,
#  "PassingCompletions": 11.0,
#  "PassingYards": 127.0,
#  "PassingCompletionPercentage": 36.8,
#  "PassingYardsPerAttempt": 2.2,
#  "PassingYardsPerCompletion": 3.2,
#  "PassingTouchdowns": 0.8,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 66.9,
#  "PassingLong": 16.3,
#  "PassingSacks": 0.8,
#  "PassingSackYards": 12.1,
#  "RushingAttempts": 3.0,
#  "RushingYards": 41.5,
#  "RushingYardsPerAttempt": 2.0,
#  "RushingTouchdowns": 0.0,
#  "RushingLong": 25.7,
#  "ReceivingTargets": 0.3,
#  "Receptions": 0.3,
#  "ReceivingYards": 5.2,
#  "ReceivingYardsPerReception": 5.2,
#  "ReceivingTouchdowns": 0.3,
# ...

# %%
wk17act_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "Activated", "Played", "Started", "FantasyPoints", "FantasyPointsPPR", "OpponentRank", "OpponentPositionRank"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk17act_df 
for i in range(0,len(response_17a)):
    currentItem = response_17a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk17act_df.loc[i] = [response_17a[i]["Week"],response_17a[i]["PlayerID"], response_17a[i]["Name"],response_17a[i]["Team"], response_17a[i]["Position"], response_17a[i]["Activated"], response_17a[i]["Played"], response_17a[i]["Started"], response_17a[i]["FantasyPoints"], response_17a[i]["FantasyPointsPPR"], response_17a[i]["OpponentRank"], response_17a[i]["OpponentPositionRank"]]

# %%
wk17act_df
# Out:
#      Week PlayerID             Name Team Position Activated Played Started  \
# 0      17    13320       Cam Newton   NE       QB         1      1       1
# 1      17    21682  Jonathan Taylor  IND       RB         1      1       1
# 2      17    17959    Derrick Henry  TEN       RB         1      1       1
# 3      17    14252     Kirk Cousins  MIN       QB         1      1       1
# 4      17    21681   Justin Herbert  LAC       QB         1      1       1
# ...   ...      ...              ...  ...      ...       ...    ...     ...
# 1901   17    18104     Nate Sudfeld  PHI       QB         1      1       0
# 1902   17    19023     Mack Hollins  MIA       WR         1      1       0
# 1903   17    18118    Brandon Allen  CIN       QB         1      1       1
# 1904   17    19044      Jamal Agnew  DET       WR         1      1       1
# 1905   17    19191      P.J. Walker  CAR       QB         1      1       0
#
# ...

# %%
#Create concatenated season of actual stats df 
#Join using concatenation
df_2020_act= [wk1act_df,wk2act_df,wk3act_df,wk4act_df,wk5act_df,wk6act_df,wk7act_df,wk8act_df,wk9act_df,wk10act_df,wk11act_df,wk12act_df,wk13act_df,wk14act_df,wk15act_df,wk16act_df,wk17act_df]
actual2020df = pd.concat(df_2020_act)
actual2020df
# Out:
#      Week PlayerID            Name Team Position Activated Played Started  \
# 0       1    20824     Josh Jacobs   LV       RB         1      1       1
# 1       1    14536  Russell Wilson  SEA       QB         1      1       1
# 2       1     2593   Aaron Rodgers   GB       QB         1      1       1
# 3       1    19801      Josh Allen  BUF       QB         1      1       1
# 4       1    16470   Davante Adams   GB       WR         1      1       1
# ...   ...      ...             ...  ...      ...       ...    ...     ...
# 1901   17    18104    Nate Sudfeld  PHI       QB         1      1       0
# 1902   17    19023    Mack Hollins  MIA       WR         1      1       0
# 1903   17    18118   Brandon Allen  CIN       QB         1      1       1
# 1904   17    19044     Jamal Agnew  DET       WR         1      1       1
# 1905   17    19191     P.J. Walker  CAR       QB         1      1       0
#
#       FantasyPoints  FantasyPointsPPR OpponentRank OpponentPositionRank
# ...

# %%
actual2020df.to_csv('2020_ACTDATA_TBG.csv', index = False)

# %%
actual2020df = actual2020df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
actual2020df

# %%
playergroup2020 = actual2020df.groupby('Name').agg({'ActFantasyPoints': ['sum']})
playergroup2020

# %%
print(len(actual2020df))

# %%
proj2020 = proj2020.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
proj2020

# %%
print(len(proj2020))

# %%
playergroup2020proj = proj2020.groupby('Name').agg({'ProjFantasyPoints': ['sum']})
playergroup2020proj

# %%
newproj2020 = proj2020[['Name', 'Week', 'ProjFantasyPoints']]
newproj2020

# %%
new_df = pd.merge(newproj2020, actual2020df,  how='left', left_on=['Name','Week'], right_on = ['Name','Week'])
new_df

# %%
ProjVsAct_df = new_df[new_df['PlayerID'].notna()]
ProjVsAct_df

# %%
print(len(ProjVsAct_df))

# %%
agg2020 = ProjVsAct_df.groupby('Name').agg({'ProjFantasyPoints': ['sum'], 'ActFantasyPoints': ['sum']})
agg2020

# %%
agg2020['%_difference'] = agg2020['ProjFantasyPoints'] - agg2020['ActFantasyPoints']
agg2020

# %%
ProjVsAct_df['%_difference'] = (ProjVsAct_df['ProjFantasyPoints'] - ProjVsAct_df['ActFantasyPoints'])/ProjVsAct_df['ActFantasyPoints']
ProjVsAct_df

# %%
ax1 = ProjVsAct_df.plot.scatter(x='OpponentPositionRank',y='%_difference',c='DarkBlue')
