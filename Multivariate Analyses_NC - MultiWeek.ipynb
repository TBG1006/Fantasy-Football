# %%
#import dependencies
import pandas as pd
import requests
import time
import json
# from sqlalchemy.ext.automap import automap_base
# from sqlalchemy.orm import Session
# from sqlalchemy import create_engine, func,inspect
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2020 WK 1-17 Actuals New Data

# %%
# week 1  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/1?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
print(json.dumps(response_1a[0],indent=1))
# Out:
# {
#  "GameKey": "202010105",
#  "PlayerID": 20824,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-13T13:00:00",
#  "Week": 1,
#  "Team": "LV",
#  "Opponent": "CAR",
#  "HomeOrAway": "AWAY",
#  "Number": 28,
#  "Name": "Josh Jacobs",
#  "Position": "RB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 35.6,
#  "RushingYards": 132.4,
#  "RushingYardsPerAttempt": 7.5,
#  "RushingTouchdowns": 6.1,
#  "RushingLong": 19.9,
#  "ReceivingTargets": 12.2,
#  "Receptions": 8.1,
#  "ReceivingYards": 65.5,
#  "ReceivingYardsPerReception": 16.4,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk1act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk1act_df 
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk1act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk1act_df.head()
# Out:
#   Week            Name  FantasyPoints
# 0    1     Josh Jacobs           45.4
# 1    1  Russell Wilson           45.3
# 2    1   Aaron Rodgers           43.8
# 3    1      Josh Allen           40.1
# 4    1   Davante Adams           39.3

# %%
wk1act_df = wk1act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk1act_df
# Out:
#      Week             Name  ActFantasyPoints
# 0       1      Josh Jacobs              45.4
# 1       1   Russell Wilson              45.3
# 2       1    Aaron Rodgers              43.8
# 3       1       Josh Allen              40.1
# 4       1    Davante Adams              39.3
# ...   ...              ...               ...
# 1804    1     Nick Vannett              -0.9
# 1805    1   Patrick Ricard              -1.7
# 1806    1  Sharrod Neasman              -2.6
# 1807    1     Mike Edwards              -2.8
# 1808    1     Jamie Gillan              -3.1
#
# [1809 rows x 3 columns]

# %%
# week 2  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/2?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
print(json.dumps(response_1a[0],indent=1))
# Out:
# {
#  "GameKey": "202010212",
#  "PlayerID": 19045,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-20T13:00:00",
#  "Week": 2,
#  "Team": "GB",
#  "Opponent": "DET",
#  "HomeOrAway": "HOME",
#  "Number": 33,
#  "Name": "Aaron Jones",
#  "Position": "RB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 0.0,
#  "PassingCompletions": 0.0,
#  "PassingYards": 0.0,
#  "PassingCompletionPercentage": 0.0,
#  "PassingYardsPerAttempt": 0.0,
#  "PassingYardsPerCompletion": 0.0,
#  "PassingTouchdowns": 0.0,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 0.0,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 18.2,
#  "RushingYards": 170.0,
#  "RushingYardsPerAttempt": 9.5,
#  "RushingTouchdowns": 2.0,
#  "RushingLong": 75.9,
#  "ReceivingTargets": 8.2,
#  "Receptions": 4.1,
#  "ReceivingYards": 68.8,
#  "ReceivingYardsPerReception": 17.2,
#  "ReceivingTouchdowns": 1.0,
# ...

# %%
wk2act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk2act_df 
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk2act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk2act_df.head()
wk2act_df = wk2act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk2act_df
# Out:
#      Week             Name  ActFantasyPoints
# 0       2      Aaron Jones              42.1
# 1       2     Dak Prescott              40.3
# 2       2       Cam Newton              35.0
# 3       2       Josh Allen              34.9
# 4       2   Russell Wilson              33.8
# ...   ...              ...               ...
# 1810    2      J.J. Taylor              -0.1
# 1811    2      Keke Coutee              -0.9
# 1812    2        Drew Lock              -1.2
# 1813    2     Kirk Cousins              -1.5
# 1814    2  Benny Snell Jr.              -1.9
#
# [1815 rows x 3 columns]

# %%
# week 3  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/3?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
print(json.dumps(response_1a[0],indent=1))
wk3act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk3act_df 
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk3act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk3act_df.head()
wk3act_df = wk3act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk3act_df
# Out:
# {
#  "GameKey": "202010303",
#  "PlayerID": 18890,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-28T20:15:00",
#  "Week": 3,
#  "Team": "KC",
#  "Opponent": "BAL",
#  "HomeOrAway": "AWAY",
#  "Number": 15,
#  "Name": "Patrick Mahomes",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 47.3,
#  "PassingCompletions": 34.9,
#  "PassingYards": 433.9,
#  "PassingCompletionPercentage": 83.2,
#  "PassingYardsPerAttempt": 10.4,
#  "PassingYardsPerCompletion": 14.0,
#  "PassingTouchdowns": 5.1,
#  "PassingInterceptions": 0.0,
#  "PassingRating": 150.5,
#  "PassingLong": 55.2,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 5.1,
#  "RushingYards": 29.3,
#  "RushingYardsPerAttempt": 8.3,
#  "RushingTouchdowns": 1.3,
#  "RushingLong": 13.5,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
# ...

# %%
# week 4  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/4?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
print(json.dumps(response_1a[0],indent=1))
wk4act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
    wk4act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk4act_df = wk4act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk4act_df
# Out:
# {
#  "GameKey": "202010409",
#  "PlayerID": 18055,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-10-04T13:00:00",
#  "Week": 4,
#  "Team": "DAL",
#  "Opponent": "CLE",
#  "HomeOrAway": "HOME",
#  "Number": 4,
#  "Name": "Dak Prescott",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 19.4,
#  "PassingCompletions": 13.7,
#  "PassingYards": 168.2,
#  "PassingCompletionPercentage": 23.7,
#  "PassingYardsPerAttempt": 1.0,
#  "PassingYardsPerCompletion": 1.4,
#  "PassingTouchdowns": 0.4,
#  "PassingInterceptions": 0.1,
#  "PassingRating": 37.8,
#  "PassingLong": 14.4,
#  "PassingSacks": 0.3,
#  "PassingSackYards": 2.4,
#  "RushingAttempts": 0.2,
#  "RushingYards": 1.3,
#  "RushingYardsPerAttempt": 0.7,
#  "RushingTouchdowns": 0.0,
#  "RushingLong": 1.2,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
# week 5  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/5?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
wk5act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
    wk5act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk5act_df = wk5act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk5act_df
# Out:
#      Week              Name  ActFantasyPoints
# 0       5    Chase Claypool              25.9
# 1       5    Ryan Tannehill              21.8
# 2       5   Patrick Mahomes              21.6
# 3       5  Ryan Fitzpatrick              20.1
# 4       5    Justin Herbert              19.9
# ...   ...               ...               ...
# 1590    5     Andre Roberts              -0.3
# 1591    5  Jakeem Grant Sr.              -0.4
# 1592    5   Jimmy Garoppolo              -0.7
# 1593    5       Mike Thomas              -0.9
# 1594    5   Ke'Shawn Vaughn              -1.1
#
# [1595 rows x 3 columns]

# %%
# week 6  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/6?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
wk6act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
    wk6act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk6act_df = wk6act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk6act_df
# Out:
#      Week                Name  ActFantasyPoints
# 0       6       Derrick Henry              43.7
# 1       6      Deshaun Watson              36.4
# 2       6           Matt Ryan              36.0
# 3       6    Justin Jefferson              34.9
# 4       6        Carson Wentz              33.5
# ...   ...                 ...               ...
# 1607    6  Reggie Robinson II               0.0
# 1608    6         Ben DiNucci               0.0
# 1609    6        Rashad Smith               0.0
# 1610    6       Mason Rudolph              -0.1
# 1611    6      Jordan Wilkins              -0.1
#
# [1612 rows x 3 columns]

# %%
# week 7  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/7?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
wk7act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
    wk7act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk7act_df = wk7act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk7act_df
# Out:
#      Week             Name  ActFantasyPoints
# 0       7   Justin Herbert              39.4
# 1       7    Tyler Lockett              38.9
# 2       7     Kyler Murray              38.0
# 3       7        Tom Brady              37.7
# 4       7       Joe Burrow              34.4
# ...   ...              ...               ...
# 1606    7        Tim Boyle              -0.1
# 1607    7  Jerick McKinnon              -0.1
# 1608    7       Cam Newton              -0.2
# 1609    7   Chase Claypool              -0.2
# 1610    7   Dede Westbrook              -2.0
#
# [1611 rows x 3 columns]

# %%
# week 8  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/8?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
wk8act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
    wk8act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk8act_df = wk8act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk8act_df
# Out:
#      Week             Name  ActFantasyPoints
# 0       8      Dalvin Cook              14.7
# 1       8  Patrick Mahomes              11.6
# 2       8   Russell Wilson               2.9
# 3       8       DK Metcalf               2.8
# 4       8  Robert Spillane               2.5
# ...   ...              ...               ...
# 1616    8     Khalil Davis               0.0
# 1617    8         Cam Gill               0.0
# 1618    8   Cedrick Wilson              -0.3
# 1619    8    Chris Herndon              -0.5
# 1620    8     Dante Pettis              -0.6
#
# [1621 rows x 3 columns]

# %%
# week 9  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/9?key=3b5fde40e15048148341780099372fc3"
response_1a = requests.get(query_url).json()
wk9act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response_1a)):
    currentItem = response_1a[i]
    wk9act_df.loc[i] = [response_1a[i]["Week"],response_1a[i]["Name"], response_1a[i]["FantasyPoints"]]
wk9act_df = wk9act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk9act_df
# Out:
#      Week                  Name  ActFantasyPoints
# 0       9          Kyler Murray              39.6
# 1       9           Dalvin Cook              38.8
# 2       9            Josh Allen              37.6
# 3       9       Patrick Mahomes              32.9
# 4       9             Drew Lock              30.5
# ...   ...                   ...               ...
# 1631    9        Devin Duvernay              -0.1
# 1632    9  Laviska Shenault Jr.              -0.1
# 1633    9        Blaine Gabbert              -0.1
# 1634    9            Blake Bell              -0.4
# 1635    9         K.J. Hill Jr.              -2.1
#
# [1636 rows x 3 columns]

# %%
# week 10  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/10?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk10act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk10act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk10act_df = wk10act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk10act_df
# Out:
#      Week                Name  ActFantasyPoints
# 0      10           Tom Brady              48.1
# 1      10        Kyler Murray              45.2
# 2      10  Ben Roethlisberger              44.3
# 3      10        Alvin Kamara              42.0
# 4      10          Josh Allen              39.8
# ...   ...                 ...               ...
# 1616   10        C.J. Prosise              -0.3
# 1617   10          Alex Armah              -0.8
# 1618   10          Ted Karras              -3.0
# 1619   10       Alex Erickson              -3.0
# 1620   10       Dwayne Harris              -3.0
#
# [1621 rows x 3 columns]

# %%
# week 11  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/11?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk11act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk11act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk11act_df = wk11act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk11act_df
# Out:
#      Week              Name  ActFantasyPoints
# 0      11    Deshaun Watson              22.8
# 1      11    Justin Herbert              20.2
# 2      11      Adam Thielen              17.7
# 3      11       Taysom Hill              17.6
# 4      11        Jared Goff              16.8
# ...   ...               ...               ...
# 1630   11       Mo Alie-Cox              -0.3
# 1631   11        Jake Luton              -1.4
# 1632   11      Frank Ragnow              -1.5
# 1633   11  Darrius Shepherd              -1.5
# 1634   11           Ty Long              -2.0
#
# [1635 rows x 3 columns]

# %%
# week 12  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/12?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk12act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk12act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk12act_df = wk12act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk12act_df
# Out:
#      Week                   Name  ActFantasyPoints
# 0      12            Tyreek Hill              64.8
# 1      12          Derrick Henry              52.7
# 2      12         Deshaun Watson              47.8
# 3      12           Jeremy Chinn              46.2
# 4      12         Antonio Gibson              45.6
# ...   ...                    ...               ...
# 1874   12            K.J. Hamler              -1.2
# 1875   12          Patrick Laird              -1.6
# 1876   12    Ray-Ray McCloud III              -1.7
# 1877   12  Lloyd Cushenberry III              -2.9
# 1878   12         Kendall Hinton              -4.0
#
# [1879 rows x 3 columns]

# %%
# week 13  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/13?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk13act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk13act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk13act_df = wk13act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk13act_df
# Out:
#      Week                      Name  ActFantasyPoints
# 0      13             Darren Waller              21.1
# 1      13                Derek Carr              20.9
# 2      13                Josh Allen              19.9
# 3      13            Baker Mayfield              18.8
# 4      13            Ryan Tannehill              18.2
# ...   ...                       ...               ...
# 1731   13               Ryan Finley              -0.3
# 1732   13  Marquez Valdes-Scantling              -0.3
# 1733   13              Chris Conley              -0.5
# 1734   13             Tevin Coleman              -0.7
# 1735   13            Nsimba Webster              -1.3
#
# [1736 rows x 3 columns]

# %%
# week 14  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/14?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk14act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk14act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk14act_df = wk14act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk14act_df
# Out:
#      Week             Name  ActFantasyPoints
# 0      14   Haason Reddick              54.1
# 1      14    Lamar Jackson              48.0
# 2      14    Derrick Henry              47.1
# 3      14    Aaron Rodgers              42.5
# 4      14   Baker Mayfield              41.3
# ...   ...              ...               ...
# 1867   14   Trenton Cannon              -0.3
# 1868   14  Jacoby Brissett              -0.3
# 1869   14  Ke'Shawn Vaughn              -0.4
# 1870   14    Alex Erickson              -1.5
# 1871   14       Colt McCoy              -1.8
#
# [1872 rows x 3 columns]

# %%
# week 15  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/15?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk15act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk15act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk15act_df = wk15act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk15act_df
# Out:
#      Week                 Name  ActFantasyPoints
# 0      15          Jalen Hurts              22.4
# 1      15           Josh Allen              22.3
# 2      15       Ryan Tannehill              22.0
# 3      15         Kyler Murray              19.7
# 4      15        Lamar Jackson              17.3
# ...   ...                  ...               ...
# 1874   15  Ray-Ray McCloud III              -0.1
# 1875   15       Logan Woodside              -0.2
# 1876   15         Theo Riddick              -0.3
# 1877   15  JuJu Smith-Schuster              -0.3
# 1878   15        Andre Roberts              -1.2
#
# [1879 rows x 3 columns]

# %%
# week 16  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/16?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk16act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk16act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk16act_df = wk16act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk16act_df
# Out:
#      Week            Name  ActFantasyPoints
# 0      16    Alvin Kamara              69.6
# 1      16    Stefon Diggs              42.5
# 2      16      Josh Allen              42.3
# 3      16   Davante Adams              42.1
# 4      16      Mike Evans              39.4
# ...   ...             ...               ...
# 1879   16      Nick Foles              -0.3
# 1880   16       Tim Boyle              -0.4
# 1881   16   Sammy Watkins              -0.8
# 1882   16  Brandon Powell              -2.4
# 1883   16   Keisean Nixon              -2.6
#
# [1884 rows x 3 columns]

# %%
# week 17  Actual

query_url = f"https://api.sportsdata.io/v3/nfl/stats/json/PlayerGameStatsByWeek/2020reg/17?key=3b5fde40e15048148341780099372fc3"
response = requests.get(query_url).json()
wk17act_df = pd.DataFrame(columns=["Week", "Name","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk17act_df.loc[i] = [response[i]["Week"],response[i]["Name"], response[i]["FantasyPoints"]]
wk17act_df = wk17act_df.rename(columns={"FantasyPoints": "ActFantasyPoints"})
wk17act_df
# Out:
#      Week             Name  ActFantasyPoints
# 0      17       Cam Newton              19.7
# 1      17  Jonathan Taylor              19.6
# 2      17    Derrick Henry              18.4
# 3      17     Kirk Cousins              18.0
# 4      17   Justin Herbert              17.3
# ...   ...              ...               ...
# 1901   17     Nate Sudfeld              -0.8
# 1902   17     Mack Hollins              -0.9
# 1903   17    Brandon Allen              -1.0
# 1904   17      Jamal Agnew              -1.0
# 1905   17      P.J. Walker              -1.2
#
# [1906 rows x 3 columns]

# %%
act2020DF = pd.concat([wk1act_df,wk2act_df,wk3act_df,wk4act_df,wk5act_df,wk6act_df,wk7act_df,
                       wk8act_df,wk9act_df,wk10act_df,wk11act_df,wk12act_df,
                       wk13act_df,wk14act_df,wk15act_df,wk16act_df,wk17act_df])
# ,wk15act_df,wk16act_df,wk17act_df
act2020DF
# Out:
#      Week            Name  ActFantasyPoints
# 0       1     Josh Jacobs              45.4
# 1       1  Russell Wilson              45.3
# 2       1   Aaron Rodgers              43.8
# 3       1      Josh Allen              40.1
# 4       1   Davante Adams              39.3
# ...   ...             ...               ...
# 1901   17    Nate Sudfeld              -0.8
# 1902   17    Mack Hollins              -0.9
# 1903   17   Brandon Allen              -1.0
# 1904   17     Jamal Agnew              -1.0
# 1905   17     P.J. Walker              -1.2
#
# [29626 rows x 3 columns]

# %% [markdown]
# # 2020 WK 1 Projected New Data

# %%
#week 1 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/1?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
print(json.dumps(response[0],indent=1))
# Out:
# {
#  "GameKey": "202010103",
#  "PlayerID": 19781,
#  "SeasonType": 1,
#  "Season": 2020,
#  "GameDate": "2020-09-13T13:00:00",
#  "Week": 1,
#  "Team": "BAL",
#  "Opponent": "CLE",
#  "HomeOrAway": "HOME",
#  "Number": 8,
#  "Name": "Lamar Jackson",
#  "Position": "QB",
#  "PositionCategory": "OFF",
#  "Activated": 1,
#  "Played": 1,
#  "Started": 1,
#  "PassingAttempts": 22.4,
#  "PassingCompletions": 13.7,
#  "PassingYards": 165.7,
#  "PassingCompletionPercentage": 42.2,
#  "PassingYardsPerAttempt": 3.7,
#  "PassingYardsPerCompletion": 6.2,
#  "PassingTouchdowns": 1.0,
#  "PassingInterceptions": 0.4,
#  "PassingRating": 63.7,
#  "PassingLong": 0.0,
#  "PassingSacks": 0.0,
#  "PassingSackYards": 0.0,
#  "RushingAttempts": 6.2,
#  "RushingYards": 42.0,
#  "RushingYardsPerAttempt": 2.5,
#  "RushingTouchdowns": 0.2,
#  "RushingLong": 0.0,
#  "ReceivingTargets": 0.0,
#  "Receptions": 0.0,
#  "ReceivingYards": 0.0,
#  "ReceivingYardsPerReception": 0.0,
#  "ReceivingTouchdowns": 0.0,
# ...

# %%
wk1proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
# wk1_df = pd.DataFrame(columns=["PlayerID"])
wk1proj_df 
for i in range(0,len(response)):
    currentItem = response[i]
#     wk1_df.loc[i] = [response[i]["PlayerID"]]
    wk1proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk1proj_df.head()
# Out:
#   Week PlayerID             Name Team Position  PassingYards Played  \
# 0    1    19781    Lamar Jackson  BAL       QB         165.7      1
# 1    1    18890  Patrick Mahomes   KC       QB         223.6      1
# 2    1    18055     Dak Prescott  DAL       QB         197.5      1
# 3    1    14536   Russell Wilson  SEA       QB         187.1      1
# 4    1    18857   Deshaun Watson  HOU       QB         185.2      1
#
#    PassingTouchdowns  PassingInterceptions  RushingTouchdowns  ReceivingYards  \
# 0                1.0                   0.4                0.2             0.0
# 1                1.2                   0.3                0.1             0.0
# 2                1.0                   0.4                0.1             0.0
# 3                1.0                   0.2                0.1             0.0
# 4                0.8                   0.5                0.2             0.0
#
#   OpponentPositionRank  FantasyPoints
# 0                   15           16.7
# ...

# %%
wk1proj_df = wk1proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk1proj_df
# Out:
#     Week PlayerID                 Name Team Position  PassingYards Played  \
# 0      1    19781        Lamar Jackson  BAL       QB         165.7      1
# 1      1    18890      Patrick Mahomes   KC       QB         223.6      1
# 2      1    18055         Dak Prescott  DAL       QB         197.5      1
# 3      1    14536       Russell Wilson  SEA       QB         187.1      1
# 4      1    18857       Deshaun Watson  HOU       QB         185.2      1
# ..   ...      ...                  ...  ...      ...           ...    ...
# 799    1    22437            Jake Burt   NE       TE           0.0      0
# 800    1    22456        Chase Harrell   SF       TE           0.0      0
# 801    1    22458         Farrod Green  IND       TE           0.0      0
# 802    1    19961  Ray-Ray McCloud III  PIT       WR           0.0      1
# 803    1    19184          JoJo Natson  CLE       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 2 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/2?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk2proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk2proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk2proj_df = wk2proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk2proj_df
# Out:
#     Week PlayerID                 Name Team Position  PassingYards Played  \
# 0      2    19781        Lamar Jackson  BAL       QB         155.5      1
# 1      2    18890      Patrick Mahomes   KC       QB         189.2      1
# 2      2    18055         Dak Prescott  DAL       QB         190.6      1
# 3      2    19801           Josh Allen  BUF       QB         151.6      1
# 4      2    20889         Kyler Murray  ARI       QB         160.9      1
# ..   ...      ...                  ...  ...      ...           ...    ...
# 813    2    22437            Jake Burt   NE       TE           0.0      0
# 814    2    22441      Nathan Cottrell  JAX       RB           0.0      1
# 815    2    22456        Chase Harrell   SF       TE           0.0      0
# 816    2    19961  Ray-Ray McCloud III  PIT       WR           0.0      1
# 817    2    19184          JoJo Natson  CLE       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 3 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/3?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk3proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk3proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk3proj_df = wk3proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk3proj_df
# Out:
#     Week PlayerID             Name Team Position  PassingYards Played  \
# 0      3    19781    Lamar Jackson  BAL       QB         100.9      1
# 1      3    20889     Kyler Murray  ARI       QB         114.8      1
# 2      3    14536   Russell Wilson  SEA       QB         118.4      1
# 3      3    13320       Cam Newton   NE       QB          97.8      1
# 4      3    18890  Patrick Mahomes   KC       QB         121.2      1
# ..   ...      ...              ...  ...      ...           ...    ...
# 830    3    22436     Rashod Berry   NE       TE           0.0      0
# 831    3    22437        Jake Burt   NE       TE           0.0      0
# 832    3    22441  Nathan Cottrell  JAX       RB           0.0      1
# 833    3    22456    Chase Harrell   SF       TE           0.0      0
# 834    3    22458     Farrod Green  IND       TE           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 4 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/4?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk4proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk4proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk4proj_df = wk4proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk4proj_df
# Out:
#     Week PlayerID             Name Team Position  PassingYards Played  \
# 0      4    19781    Lamar Jackson  BAL       QB         321.0      1
# 1      4    14536   Russell Wilson  SEA       QB         405.4      1
# 2      4    18890  Patrick Mahomes   KC       QB         412.7      1
# 3      4    19801       Josh Allen  BUF       QB         359.5      1
# 4      4    18055     Dak Prescott  DAL       QB         435.0      1
# ..   ...      ...              ...  ...      ...           ...    ...
# 788    4    22437        Jake Burt   NE       TE           0.0      0
# 789    4    22441  Nathan Cottrell  JAX       RB           0.0      1
# 790    4    22456    Chase Harrell   SF       TE           0.0      0
# 791    4    22458     Farrod Green  IND       TE           0.0      1
# 792    4     5834       Matt Moore   KC       QB           8.5      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 5 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/5?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk5proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk5proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk5proj_df = wk5proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk5proj_df
# Out:
#     Week PlayerID                 Name Team Position  PassingYards Played  \
# 0      5    18890      Patrick Mahomes   KC       QB         440.5      1
# 1      5    14536       Russell Wilson  SEA       QB         440.8      1
# 2      5    19781        Lamar Jackson  BAL       QB         342.8      1
# 3      5    18055         Dak Prescott  DAL       QB         446.7      1
# 4      5    19801           Josh Allen  BUF       QB         384.1      1
# ..   ...      ...                  ...  ...      ...           ...    ...
# 729    5    22433           John Hurst   TB       WR           0.0      1
# 730    5    22441      Nathan Cottrell  JAX       RB           0.0      1
# 731    5    22456        Chase Harrell   SF       TE           0.0      0
# 732    5    22458         Farrod Green  IND       TE           0.0      1
# 733    5    19961  Ray-Ray McCloud III  PIT       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 6 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/6?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk6proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk6proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk6proj_df = wk6proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk6proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      6    18890   Patrick Mahomes   KC       QB         346.5      1
# 1      6    20889      Kyler Murray  ARI       QB         298.1      1
# 2      6    19781     Lamar Jackson  BAL       QB         252.8      1
# 3      6    19801        Josh Allen  BUF       QB         288.8      1
# 4      6    18857    Deshaun Watson  HOU       QB         312.1      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 732    6    22441   Nathan Cottrell  JAX       RB           0.0      1
# 733    6    22456     Chase Harrell   SF       TE           0.0      0
# 734    6    22458      Farrod Green  IND       TE           0.0      1
# 735    6    22477  Dominique Dafney   GB       TE           0.0      0
# 736    6    22482   Sergio Castillo  NYJ        K           0.0      0
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 7 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/7?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk7proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk7proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk7proj_df = wk7proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk7proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      7    14536    Russell Wilson  SEA       QB         512.2      1
# 1      7    20889      Kyler Murray  ARI       QB         466.7      1
# 2      7    18890   Patrick Mahomes   KC       QB         511.7      1
# 3      7    18857    Deshaun Watson  HOU       QB         502.8      1
# 4      7    19801        Josh Allen  BUF       QB         455.4      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 734    7    22441   Nathan Cottrell  JAX       RB           0.0      1
# 735    7    22456     Chase Harrell   SF       TE           0.0      0
# 736    7    22477  Dominique Dafney   GB       TE           0.0      0
# 737    7    22482   Sergio Castillo  NYJ        K           0.0      0
# 738    7    23101      Parker Hesse  TEN       TE           0.0      0
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 8 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/8?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk8proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk8proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk8proj_df = wk8proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk8proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      8    18890   Patrick Mahomes   KC       QB         132.9      1
# 1      8    14536    Russell Wilson  SEA       QB         131.0      1
# 2      8    19781     Lamar Jackson  BAL       QB          98.6      1
# 3      8     2593     Aaron Rodgers   GB       QB         121.0      1
# 4      8    19801        Josh Allen  BUF       QB         104.5      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 733    8    22458      Farrod Green  IND       TE           0.0      1
# 734    8    22477  Dominique Dafney   GB       TE           0.0      0
# 735    8    22482   Sergio Castillo  NYJ        K           0.0      0
# 736    8    23101      Parker Hesse  TEN       TE           0.0      0
# 737    8    11565     Andre Roberts  BUF       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 9 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/9?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk9proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk9proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk9proj_df = wk9proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk9proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      9    14536    Russell Wilson  SEA       QB         265.2      1
# 1      9    20889      Kyler Murray  ARI       QB         230.2      1
# 2      9    18890   Patrick Mahomes   KC       QB         270.5      1
# 3      9    18857    Deshaun Watson  HOU       QB         261.0      1
# 4      9    19801        Josh Allen  BUF       QB         244.9      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 735    9    22458      Farrod Green  IND       TE           0.0      1
# 736    9    22477  Dominique Dafney   GB       TE           0.0      0
# 737    9    23101      Parker Hesse  TEN       TE           0.0      0
# 738    9    18973     C.J. Beathard   SF       QB           3.5      1
# 739    9    19854      Dante Pettis  NYG       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 10 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/10?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk10proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk10proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk10proj_df = wk10proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk10proj_df
# Out:
#     Week PlayerID               Name Team Position  PassingYards Played  \
# 0     10    20889       Kyler Murray  ARI       QB         431.5      1
# 1     10    19801         Josh Allen  BUF       QB         443.9      1
# 2     10    14536     Russell Wilson  SEA       QB         459.5      1
# 3     10    19781      Lamar Jackson  BAL       QB         328.6      1
# 4     10     2593      Aaron Rodgers   GB       QB         414.7      1
# ..   ...      ...                ...  ...      ...           ...    ...
# 742   10    22456      Chase Harrell   SF       TE           0.0      0
# 743   10    22458       Farrod Green  IND       TE           0.0      1
# 744   10    22475  Paul Quessenberry   NE       TE           0.0      0
# 745   10    22477   Dominique Dafney   GB       TE           0.0      0
# 746   10    23101       Parker Hesse  TEN       TE           0.0      0
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 11 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/11?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk11proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk11proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk11proj_df = wk11proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk11proj_df
# Out:
#     Week PlayerID               Name Team Position  PassingYards Played  \
# 0     11    20889       Kyler Murray  ARI       QB         228.6      1
# 1     11    14536     Russell Wilson  SEA       QB         239.1      1
# 2     11    18890    Patrick Mahomes   KC       QB         244.1      1
# 3     11    19781      Lamar Jackson  BAL       QB         176.3      1
# 4     11    21681     Justin Herbert  LAC       QB         230.9      1
# ..   ...      ...                ...  ...      ...           ...    ...
# 739   11    22458       Farrod Green  IND       TE           0.0      1
# 740   11    22473       Connor Davis  NYJ       TE           0.0      0
# 741   11    22475  Paul Quessenberry   NE       TE           0.0      0
# 742   11    22477   Dominique Dafney   GB       TE           0.0      0
# 743   11    23101       Parker Hesse  TEN       TE           0.0      0
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 12 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/12?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk12proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk12proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk12proj_df = wk12proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk12proj_df
# Out:
#     Week PlayerID               Name Team Position  PassingYards Played  \
# 0     12    18890    Patrick Mahomes   KC       QB         477.8      1
# 1     12    20889       Kyler Murray  ARI       QB         393.3      1
# 2     12    18857     Deshaun Watson  HOU       QB         436.2      1
# 3     12    19801         Josh Allen  BUF       QB         398.6      1
# 4     12    14536     Russell Wilson  SEA       QB         427.4      1
# ..   ...      ...                ...  ...      ...           ...    ...
# 861   12    22458       Farrod Green  IND       TE           0.0      1
# 862   12    22473       Connor Davis  NYJ       TE           0.0      0
# 863   12    22475  Paul Quessenberry   NE       TE           0.0      0
# 864   12    22477   Dominique Dafney   GB       TE           0.0      0
# 865   12    23101       Parker Hesse  TEN       TE           0.0      0
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 13 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/13?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk13proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk13proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk13proj_df = wk13proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk13proj_df
# Out:
#     Week PlayerID               Name Team Position  PassingYards Played  \
# 0     13    18890    Patrick Mahomes   KC       QB         223.4      1
# 1     13    14536     Russell Wilson  SEA       QB         214.6      1
# 2     13     2593      Aaron Rodgers   GB       QB         209.1      1
# 3     13    20889       Kyler Murray  ARI       QB         169.3      1
# 4     13    21681     Justin Herbert  LAC       QB         208.7      1
# ..   ...      ...                ...  ...      ...           ...    ...
# 802   13    22458       Farrod Green  IND       TE           0.0      1
# 803   13    22473       Connor Davis  NYJ       TE           0.0      0
# 804   13    22475  Paul Quessenberry   NE       TE           0.0      0
# 805   13    22477   Dominique Dafney   GB       TE           0.0      0
# 806   13    23101       Parker Hesse  TEN       TE           0.0      0
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 14 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/14?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk14proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk14proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk14proj_df = wk14proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk14proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0     14    18890   Patrick Mahomes   KC       QB         541.0      1
# 1     14    14536    Russell Wilson  SEA       QB         499.6      1
# 2     14     2593     Aaron Rodgers   GB       QB         536.9      1
# 3     14    21681    Justin Herbert  LAC       QB         505.3      1
# 4     14    20889      Kyler Murray  ARI       QB         428.1      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 864   14    22477  Dominique Dafney   GB       TE           0.0      0
# 865   14    22485  Taylor Russolino  DEN        K           0.0      0
# 866   14    23101      Parker Hesse  TEN       TE           0.0      0
# 867   14    11565     Andre Roberts  BUF       WR           0.0      1
# 868   14    21295    Nsimba Webster  LAR       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 15 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/15?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk15proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk15proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk15proj_df = wk15proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk15proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0     15    18890   Patrick Mahomes   KC       QB         294.3      1
# 1     15    19781     Lamar Jackson  BAL       QB         192.5      1
# 2     15     2593     Aaron Rodgers   GB       QB         268.6      1
# 3     15    20889      Kyler Murray  ARI       QB         232.8      1
# 4     15    19801        Josh Allen  BUF       QB         234.5      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 865   15    22477  Dominique Dafney   GB       TE           0.0      0
# 866   15    22485  Taylor Russolino  DEN        K           0.0      0
# 867   15    23101      Parker Hesse  TEN       TE           0.0      0
# 868   15      611        Joe Flacco  NYJ       QB           3.0      1
# 869   15    21295    Nsimba Webster  LAR       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 16 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/16?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk16proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk16proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk16proj_df = wk16proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk16proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0     16    18890   Patrick Mahomes   KC       QB         555.9      1
# 1     16    20889      Kyler Murray  ARI       QB         429.2      1
# 2     16     2593     Aaron Rodgers   GB       QB         512.7      1
# 3     16    19781     Lamar Jackson  BAL       QB         349.0      1
# 4     16    18857    Deshaun Watson  HOU       QB         471.2      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 877   16    22485  Taylor Russolino  DEN        K           0.0      0
# 878   16    23101      Parker Hesse  TEN       TE           0.0      0
# 879   16    11565     Andre Roberts  BUF       WR           0.0      1
# 880   16    16850      Sean Mannion  MIN       QB          11.7      1
# 881   16    21295    Nsimba Webster  LAR       WR           0.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
#week 17 Projected
query_url = f"https://api.sportsdata.io/v3/nfl/projections/json/PlayerGameProjectionStatsByWeek/2020REG/17?key=4339cb9aa27441699f1883848f498899"
response = requests.get(query_url).json()
wk17proj_df = pd.DataFrame(columns=["Week","PlayerID", "Name","Team", "Position", "PassingYards", "Played", "PassingTouchdowns", "PassingInterceptions", "RushingTouchdowns", "ReceivingYards", "OpponentPositionRank","FantasyPoints"])
for i in range(0,len(response)):
    currentItem = response[i]
    wk17proj_df.loc[i] = [response[i]["Week"],response[i]["PlayerID"], 
                         response[i]["Name"],response[i]["Team"], response[i]["Position"], 
                         response[i]["PassingYards"], response[i]["Played"], response[i]["PassingTouchdowns"], 
                         response[i]["PassingInterceptions"], response[i]["RushingTouchdowns"], 
                         response[i]["ReceivingYards"], response[i]["OpponentPositionRank"], response[i]["FantasyPoints"]]
wk17proj_df = wk17proj_df.rename(columns={"FantasyPoints": "ProjFantasyPoints"})
wk17proj_df
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0     17    19781     Lamar Jackson  BAL       QB         198.1      1
# 1     17    18857    Deshaun Watson  HOU       QB         264.3      1
# 2     17     2593     Aaron Rodgers   GB       QB         239.6      1
# 3     17    13799    Ryan Tannehill  TEN       QB         217.4      1
# 4     17     4314         Tom Brady   TB       QB         263.0      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 876   17    22482   Sergio Castillo  NYJ        K           0.0      1
# 877   17    22485  Taylor Russolino  DEN        K           0.0      0
# 878   17    23101      Parker Hesse  TEN       TE           0.0      0
# 879   17    21295    Nsimba Webster  LAR       WR           0.0      1
# 880   17    19763        Josh Rosen   SF       QB           5.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
proj2020DF = pd.concat([wk1proj_df,wk2proj_df,wk3proj_df,wk4proj_df,wk5proj_df,wk6proj_df,wk7proj_df,wk8proj_df,wk9proj_df,
                        wk10proj_df,wk11proj_df,wk12proj_df,wk13proj_df,wk14proj_df,wk15proj_df,wk16proj_df,wk17proj_df])
# ,wk15proj_df,wk16proj_df,wk17proj_df
proj2020DF
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      1    19781     Lamar Jackson  BAL       QB         165.7      1
# 1      1    18890   Patrick Mahomes   KC       QB         223.6      1
# 2      1    18055      Dak Prescott  DAL       QB         197.5      1
# 3      1    14536    Russell Wilson  SEA       QB         187.1      1
# 4      1    18857    Deshaun Watson  HOU       QB         185.2      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 876   17    22482   Sergio Castillo  NYJ        K           0.0      1
# 877   17    22485  Taylor Russolino  DEN        K           0.0      0
# 878   17    23101      Parker Hesse  TEN       TE           0.0      0
# 879   17    21295    Nsimba Webster  LAR       WR           0.0      1
# 880   17    19763        Josh Rosen   SF       QB           5.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
proj2020DF['Position'].unique()
# Out:
# array(['QB', 'RB', 'WR', 'TE', 'K'], dtype=object)

# %%
proj2020DF = proj2020DF[proj2020DF['Position'].isin(['QB'])]

# %%
new_df = pd.merge(act2020DF, proj2020DF,  how='left', left_on=['Name','Week'], right_on = ['Name','Week'])
new_df
# Out:
#       Week            Name  ActFantasyPoints PlayerID Team Position  \
# 0        1     Josh Jacobs              45.4      NaN  NaN      NaN
# 1        1  Russell Wilson              45.3    14536  SEA       QB
# 2        1   Aaron Rodgers              43.8     2593   GB       QB
# 3        1      Josh Allen              40.1    19801  BUF       QB
# 4        1   Davante Adams              39.3      NaN  NaN      NaN
# ...    ...             ...               ...      ...  ...      ...
# 29621   17    Nate Sudfeld              -0.8    18104  PHI       QB
# 29622   17    Mack Hollins              -0.9      NaN  NaN      NaN
# 29623   17   Brandon Allen              -1.0    18118  CIN       QB
# 29624   17     Jamal Agnew              -1.0      NaN  NaN      NaN
# 29625   17     P.J. Walker              -1.2    19191  CAR       QB
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# 0               NaN    NaN                NaN                   NaN
# ...

# %%
new_df.count()
# Out:
# Week                    29626
# Name                    29626
# ActFantasyPoints        29626
# PlayerID                 1395
# Team                     1395
# Position                 1395
# PassingYards             1395
# Played                   1395
# PassingTouchdowns        1395
# PassingInterceptions     1395
# RushingTouchdowns        1395
# ReceivingYards           1395
# OpponentPositionRank     1395
# ProjFantasyPoints        1395
# dtype: int64

# %%
new_df.isnull().values.any()
# Out:
# True

# %%
new_df['PassingYards'].isnull().values.any()
# Out:
# True

# %%
new_df['ActFantasyPoints'].isnull().values.any()
# Out:
# False

# %%
ProjVsAct_df = new_df[new_df['OpponentPositionRank'].notna()]
ProjVsAct_df
# Out:
#       Week            Name  ActFantasyPoints PlayerID Team Position  \
# 1        1  Russell Wilson              45.3    14536  SEA       QB
# 2        1   Aaron Rodgers              43.8     2593   GB       QB
# 3        1      Josh Allen              40.1    19801  BUF       QB
# 5        1   Lamar Jackson              39.2    19781  BAL       QB
# 6        1    Kyler Murray              37.5    20889  ARI       QB
# ...    ...             ...               ...      ...  ...      ...
# 29610   17   Steven Montez               0.0    21809  WAS       QB
# 29617   17  Jameis Winston              -0.1    16762   NO       QB
# 29621   17    Nate Sudfeld              -0.8    18104  PHI       QB
# 29623   17   Brandon Allen              -1.0    18118  CIN       QB
# 29625   17     P.J. Walker              -1.2    19191  CAR       QB
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# 1             187.1      1                1.0                   0.2
# ...

# %%
ProjVsAct_df.count()
# Out:
# Week                    1395
# Name                    1395
# ActFantasyPoints        1395
# PlayerID                1395
# Team                    1395
# Position                1395
# PassingYards            1395
# Played                  1395
# PassingTouchdowns       1395
# PassingInterceptions    1395
# RushingTouchdowns       1395
# ReceivingYards          1395
# OpponentPositionRank    1395
# ProjFantasyPoints       1395
# dtype: int64

# %%
ProjVsAct_df['Played'].value_counts()
# Out:
# 1    1385
# 0      10
# Name: Played, dtype: int64

# %%
ProjVsAct_df.dtypes
# Out:
# Week                     object
# Name                     object
# ActFantasyPoints        float64
# PlayerID                 object
# Team                     object
# Position                 object
# PassingYards            float64
# Played                   object
# PassingTouchdowns       float64
# PassingInterceptions    float64
# RushingTouchdowns       float64
# ReceivingYards          float64
# OpponentPositionRank     object
# ProjFantasyPoints       float64
# dtype: object

# %%
ProjVsAct_df.isnull().values.any()
# Out:
# False

# %%
ProjVsAct_df['Played'] = ProjVsAct_df['Played'].astype(float, errors = 'raise')
ProjVsAct_df['OpponentPositionRank'] = ProjVsAct_df['OpponentPositionRank'].astype(float, errors = 'raise')
ProjVsAct_df.dtypes
# Out:
# C:\Users\Thomas\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Thomas\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Week                     object
# Name                     object
# ActFantasyPoints        float64
# PlayerID                 object
# Team                     object
# ...

# %%
 # Assign the data to X and y

X = ProjVsAct_df[["PassingYards", "Played","PassingTouchdowns","PassingInterceptions","OpponentPositionRank","ProjFantasyPoints"]]
y = ProjVsAct_df["ActFantasyPoints"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (1395, 6) (1395, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
 # Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
 # Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.5248660188389799
# Testing Score: 0.5066453764999117

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), y_train - model.predict(X_train), c="blue", label="Training Data")
plt.scatter(model.predict(X_test), y_test - model.predict(X_test), c="green", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# # RB

# %%
act2020RB = pd.concat([wk1act_df,wk2act_df,wk3act_df,wk4act_df,wk5act_df,wk6act_df,wk7act_df,
                       wk8act_df,wk9act_df,wk10act_df,wk11act_df,wk12act_df,
                       wk13act_df,wk14act_df,wk15act_df,wk16act_df,wk17act_df])
# ,wk15act_df,wk16act_df,wk17act_df
act2020RB
# Out:
#      Week            Name  ActFantasyPoints
# 0       1     Josh Jacobs              45.4
# 1       1  Russell Wilson              45.3
# 2       1   Aaron Rodgers              43.8
# 3       1      Josh Allen              40.1
# 4       1   Davante Adams              39.3
# ...   ...             ...               ...
# 1901   17    Nate Sudfeld              -0.8
# 1902   17    Mack Hollins              -0.9
# 1903   17   Brandon Allen              -1.0
# 1904   17     Jamal Agnew              -1.0
# 1905   17     P.J. Walker              -1.2
#
# [29626 rows x 3 columns]

# %%
proj2020RB = pd.concat([wk1proj_df,wk2proj_df,wk3proj_df,wk4proj_df,wk5proj_df,wk6proj_df,wk7proj_df,wk8proj_df,wk9proj_df,
                        wk10proj_df,wk11proj_df,wk12proj_df,wk13proj_df,wk14proj_df,wk15proj_df,wk16proj_df,wk17proj_df])
# ,wk15proj_df,wk16proj_df,wk17proj_df
proj2020RB
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      1    19781     Lamar Jackson  BAL       QB         165.7      1
# 1      1    18890   Patrick Mahomes   KC       QB         223.6      1
# 2      1    18055      Dak Prescott  DAL       QB         197.5      1
# 3      1    14536    Russell Wilson  SEA       QB         187.1      1
# 4      1    18857    Deshaun Watson  HOU       QB         185.2      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 876   17    22482   Sergio Castillo  NYJ        K           0.0      1
# 877   17    22485  Taylor Russolino  DEN        K           0.0      0
# 878   17    23101      Parker Hesse  TEN       TE           0.0      0
# 879   17    21295    Nsimba Webster  LAR       WR           0.0      1
# 880   17    19763        Josh Rosen   SF       QB           5.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
new_dfRB = pd.merge(act2020RB, proj2020RB,  how='left', left_on=['Name','Week'], right_on = ['Name','Week'])
new_dfRB
# Out:
#       Week            Name  ActFantasyPoints PlayerID Team Position  \
# 0        1     Josh Jacobs              45.4    20824   LV       RB
# 1        1  Russell Wilson              45.3    14536  SEA       QB
# 2        1   Aaron Rodgers              43.8     2593   GB       QB
# 3        1      Josh Allen              40.1    19801  BUF       QB
# 4        1   Davante Adams              39.3    16470   GB       WR
# ...    ...             ...               ...      ...  ...      ...
# 29660   17    Nate Sudfeld              -0.8    18104  PHI       QB
# 29661   17    Mack Hollins              -0.9    19023  MIA       WR
# 29662   17   Brandon Allen              -1.0    18118  CIN       QB
# 29663   17     Jamal Agnew              -1.0    19044  DET       WR
# 29664   17     P.J. Walker              -1.2    19191  CAR       QB
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# 0               0.0      1                0.0                   0.0
# ...

# %%
new_dfRB = new_dfRB[new_dfRB['Position'].isin(['RB'])]

# %%
new_df.count()
# Out:
# Week                    29626
# Name                    29626
# ActFantasyPoints        29626
# PlayerID                 1395
# Team                     1395
# Position                 1395
# PassingYards             1395
# Played                   1395
# PassingTouchdowns        1395
# PassingInterceptions     1395
# RushingTouchdowns        1395
# ReceivingYards           1395
# OpponentPositionRank     1395
# ProjFantasyPoints        1395
# dtype: int64

# %%
new_df['PassingYards'].isnull().values.any()
# Out:
# True

# %%
ProjVsAct_df = new_df[new_df['OpponentPositionRank'].notna()]
ProjVsAct_df
# Out:
#       Week            Name  ActFantasyPoints PlayerID Team Position  \
# 1        1  Russell Wilson              45.3    14536  SEA       QB
# 2        1   Aaron Rodgers              43.8     2593   GB       QB
# 3        1      Josh Allen              40.1    19801  BUF       QB
# 5        1   Lamar Jackson              39.2    19781  BAL       QB
# 6        1    Kyler Murray              37.5    20889  ARI       QB
# ...    ...             ...               ...      ...  ...      ...
# 29610   17   Steven Montez               0.0    21809  WAS       QB
# 29617   17  Jameis Winston              -0.1    16762   NO       QB
# 29621   17    Nate Sudfeld              -0.8    18104  PHI       QB
# 29623   17   Brandon Allen              -1.0    18118  CIN       QB
# 29625   17     P.J. Walker              -1.2    19191  CAR       QB
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# 1             187.1      1                1.0                   0.2
# ...

# %%
ProjVsAct_df.isnull().values.any()
# Out:
# False

# %%
ProjVsAct_df['Played'] = ProjVsAct_df['Played'].astype(float, errors = 'raise')
ProjVsAct_df['OpponentPositionRank'] = ProjVsAct_df['OpponentPositionRank'].astype(float, errors = 'raise')
ProjVsAct_df.dtypes
# Out:
# C:\Users\Thomas\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Thomas\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Week                     object
# Name                     object
# ActFantasyPoints        float64
# PlayerID                 object
# Team                     object
# ...

# %%
 # Assign the data to X and y

X = ProjVsAct_df[["Played","RushingTouchdowns","OpponentPositionRank","ProjFantasyPoints"]]
y = ProjVsAct_df["ActFantasyPoints"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (1395, 4) (1395, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
 # Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
 # Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.4964618866001528
# Testing Score: 0.49181855129243046

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), y_train - model.predict(X_train), c="blue", label="Training Data")
plt.scatter(model.predict(X_test), y_test - model.predict(X_test), c="green", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# # WR

# %%
act2020WR = pd.concat([wk1act_df,wk2act_df,wk3act_df,wk4act_df,wk5act_df,wk6act_df,wk7act_df,
                       wk8act_df,wk9act_df,wk10act_df,wk11act_df,wk12act_df,
                       wk13act_df,wk14act_df,wk15act_df,wk16act_df,wk17act_df])
# ,wk15act_df,wk16act_df,wk17act_df
act2020WR
# Out:
#      Week            Name  ActFantasyPoints
# 0       1     Josh Jacobs              45.4
# 1       1  Russell Wilson              45.3
# 2       1   Aaron Rodgers              43.8
# 3       1      Josh Allen              40.1
# 4       1   Davante Adams              39.3
# ...   ...             ...               ...
# 1901   17    Nate Sudfeld              -0.8
# 1902   17    Mack Hollins              -0.9
# 1903   17   Brandon Allen              -1.0
# 1904   17     Jamal Agnew              -1.0
# 1905   17     P.J. Walker              -1.2
#
# [29626 rows x 3 columns]

# %%
proj2020WR = pd.concat([wk1proj_df,wk2proj_df,wk3proj_df,wk4proj_df,wk5proj_df,wk6proj_df,wk7proj_df,wk8proj_df,wk9proj_df,
                        wk10proj_df,wk11proj_df,wk12proj_df,wk13proj_df,wk14proj_df,wk15proj_df,wk16proj_df,wk17proj_df])
# ,wk15proj_df,wk16proj_df,wk17proj_df
proj2020WR
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      1    19781     Lamar Jackson  BAL       QB         165.7      1
# 1      1    18890   Patrick Mahomes   KC       QB         223.6      1
# 2      1    18055      Dak Prescott  DAL       QB         197.5      1
# 3      1    14536    Russell Wilson  SEA       QB         187.1      1
# 4      1    18857    Deshaun Watson  HOU       QB         185.2      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 876   17    22482   Sergio Castillo  NYJ        K           0.0      1
# 877   17    22485  Taylor Russolino  DEN        K           0.0      0
# 878   17    23101      Parker Hesse  TEN       TE           0.0      0
# 879   17    21295    Nsimba Webster  LAR       WR           0.0      1
# 880   17    19763        Josh Rosen   SF       QB           5.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
new_dfWR = pd.merge(act2020WR, proj2020WR,  how='left', left_on=['Name','Week'], right_on = ['Name','Week'])
new_dfWR
# Out:
#       Week            Name  ActFantasyPoints PlayerID Team Position  \
# 0        1     Josh Jacobs              45.4    20824   LV       RB
# 1        1  Russell Wilson              45.3    14536  SEA       QB
# 2        1   Aaron Rodgers              43.8     2593   GB       QB
# 3        1      Josh Allen              40.1    19801  BUF       QB
# 4        1   Davante Adams              39.3    16470   GB       WR
# ...    ...             ...               ...      ...  ...      ...
# 29660   17    Nate Sudfeld              -0.8    18104  PHI       QB
# 29661   17    Mack Hollins              -0.9    19023  MIA       WR
# 29662   17   Brandon Allen              -1.0    18118  CIN       QB
# 29663   17     Jamal Agnew              -1.0    19044  DET       WR
# 29664   17     P.J. Walker              -1.2    19191  CAR       QB
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# 0               0.0      1                0.0                   0.0
# ...

# %%
new_dfWR = new_dfWR[new_dfWR['Position'].isin(['WR'])]

# %%
new_dfWR.count()
# Out:
# Week                    3382
# Name                    3382
# ActFantasyPoints        3382
# PlayerID                3382
# Team                    3382
# Position                3382
# PassingYards            3382
# Played                  3382
# PassingTouchdowns       3382
# PassingInterceptions    3382
# RushingTouchdowns       3382
# ReceivingYards          3382
# OpponentPositionRank    3382
# ProjFantasyPoints       3382
# dtype: int64

# %%
new_dfWR['PassingYards'].isnull().values.any()
# Out:
# False

# %%
ProjVsAct_df = new_dfWR[new_dfWR['OpponentPositionRank'].notna()]
ProjVsAct_df
# Out:
#       Week                 Name  ActFantasyPoints PlayerID Team Position  \
# 4        1        Davante Adams              39.3    16470   GB       WR
# 9        1         Adam Thielen              35.6    15534  MIN       WR
# 10       1        Calvin Ridley              35.5    19802  ATL       WR
# 15       1       Darius Slayton              31.6    20943  NYG       WR
# 27       1       Robby Anderson              27.6    18187  CAR       WR
# ...    ...                  ...               ...      ...  ...      ...
# 29657   17       Tommylee Lewis              -0.1    18401   NO       WR
# 29658   17  Ray-Ray McCloud III              -0.2    19961  PIT       WR
# 29659   17         Tavon Austin              -0.7    15215   GB       WR
# 29661   17         Mack Hollins              -0.9    19023  MIA       WR
# 29663   17          Jamal Agnew              -1.0    19044  DET       WR
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# ...

# %%
ProjVsAct_df.isnull().values.any()
# Out:
# False

# %%
ProjVsAct_df['Played'] = ProjVsAct_df['Played'].astype(float, errors = 'raise')
ProjVsAct_df['OpponentPositionRank'] = ProjVsAct_df['OpponentPositionRank'].astype(float, errors = 'raise')
ProjVsAct_df.dtypes
# Out:
# Week                     object
# Name                     object
# ActFantasyPoints        float64
# PlayerID                 object
# Team                     object
# Position                 object
# PassingYards            float64
# Played                  float64
# PassingTouchdowns       float64
# PassingInterceptions    float64
# RushingTouchdowns       float64
# ReceivingYards          float64
# OpponentPositionRank    float64
# ProjFantasyPoints       float64
# dtype: object

# %%
 # Assign the data to X and y

X = ProjVsAct_df[["Played","ReceivingYards","OpponentPositionRank","ProjFantasyPoints"]]
y = ProjVsAct_df["ActFantasyPoints"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (3382, 4) (3382, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
 # Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
 # Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.3218839681679454
# Testing Score: 0.35598690265608435

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), y_train - model.predict(X_train), c="blue", label="Training Data")
plt.scatter(model.predict(X_test), y_test - model.predict(X_test), c="green", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# # TE

# %%
act2020TE = pd.concat([wk1act_df,wk2act_df,wk3act_df,wk4act_df,wk5act_df,wk6act_df,wk7act_df,
                       wk8act_df,wk9act_df,wk10act_df,wk11act_df,wk12act_df,
                       wk13act_df,wk14act_df,wk15act_df,wk16act_df,wk17act_df])
# ,wk15act_df,wk16act_df,wk17act_df
act2020TE
# Out:
#      Week            Name  ActFantasyPoints
# 0       1     Josh Jacobs              45.4
# 1       1  Russell Wilson              45.3
# 2       1   Aaron Rodgers              43.8
# 3       1      Josh Allen              40.1
# 4       1   Davante Adams              39.3
# ...   ...             ...               ...
# 1901   17    Nate Sudfeld              -0.8
# 1902   17    Mack Hollins              -0.9
# 1903   17   Brandon Allen              -1.0
# 1904   17     Jamal Agnew              -1.0
# 1905   17     P.J. Walker              -1.2
#
# [29626 rows x 3 columns]

# %%
proj2020TE = pd.concat([wk1proj_df,wk2proj_df,wk3proj_df,wk4proj_df,wk5proj_df,wk6proj_df,wk7proj_df,wk8proj_df,wk9proj_df,
                        wk10proj_df,wk11proj_df,wk12proj_df,wk13proj_df,wk14proj_df,wk15proj_df,wk16proj_df,wk17proj_df])
# ,wk15proj_df,wk16proj_df,wk17proj_df
proj2020TE
# Out:
#     Week PlayerID              Name Team Position  PassingYards Played  \
# 0      1    19781     Lamar Jackson  BAL       QB         165.7      1
# 1      1    18890   Patrick Mahomes   KC       QB         223.6      1
# 2      1    18055      Dak Prescott  DAL       QB         197.5      1
# 3      1    14536    Russell Wilson  SEA       QB         187.1      1
# 4      1    18857    Deshaun Watson  HOU       QB         185.2      1
# ..   ...      ...               ...  ...      ...           ...    ...
# 876   17    22482   Sergio Castillo  NYJ        K           0.0      1
# 877   17    22485  Taylor Russolino  DEN        K           0.0      0
# 878   17    23101      Parker Hesse  TEN       TE           0.0      0
# 879   17    21295    Nsimba Webster  LAR       WR           0.0      1
# 880   17    19763        Josh Rosen   SF       QB           5.0      1
#
#      PassingTouchdowns  PassingInterceptions  RushingTouchdowns  \
# ...

# %%
new_dfTE = pd.merge(act2020TE, proj2020TE,  how='left', left_on=['Name','Week'], right_on = ['Name','Week'])
new_dfTE
# Out:
#       Week            Name  ActFantasyPoints PlayerID Team Position  \
# 0        1     Josh Jacobs              45.4    20824   LV       RB
# 1        1  Russell Wilson              45.3    14536  SEA       QB
# 2        1   Aaron Rodgers              43.8     2593   GB       QB
# 3        1      Josh Allen              40.1    19801  BUF       QB
# 4        1   Davante Adams              39.3    16470   GB       WR
# ...    ...             ...               ...      ...  ...      ...
# 29660   17    Nate Sudfeld              -0.8    18104  PHI       QB
# 29661   17    Mack Hollins              -0.9    19023  MIA       WR
# 29662   17   Brandon Allen              -1.0    18118  CIN       QB
# 29663   17     Jamal Agnew              -1.0    19044  DET       WR
# 29664   17     P.J. Walker              -1.2    19191  CAR       QB
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# 0               0.0      1                0.0                   0.0
# ...

# %%
new_dfTE = new_dfTE[new_dfTE['Position'].isin(['TE'])]

# %%
new_dfTE['PassingYards'].isnull().values.any()
# Out:
# False

# %%
ProjVsAct_df = new_dfTE[new_dfTE['OpponentPositionRank'].notna()]
ProjVsAct_df
# Out:
#       Week             Name  ActFantasyPoints PlayerID Team Position  \
# 36       1     Mark Andrews              25.3    19803  BAL       TE
# 44       1   Dallas Goedert              22.9    19863  PHI       TE
# 60       1        Noah Fant              20.1    20753  DEN       TE
# 95       1   T.J. Hockenson              16.5    20805  DET       TE
# 106      1     Travis Kelce              15.7    15048   KC       TE
# ...    ...              ...               ...      ...  ...      ...
# 29608   17   Dallas Goedert               0.0    19863  PHI       TE
# 29615   17     Caleb Wilson               0.0    20993  PHI       TE
# 29635   17  Jeremy Sprinkle               0.0    19067  WAS       TE
# 29642   17     Marcus Baugh               0.0    20174  WAS       TE
# 29654   17       Ian Thomas              -0.1    19910  CAR       TE
#
#        PassingYards Played  PassingTouchdowns  PassingInterceptions  \
# 36              0.0      1                0.0                   0.0
# ...

# %%
ProjVsAct_df.isnull().values.any()
# Out:
# False

# %%
ProjVsAct_df['Played'] = ProjVsAct_df['Played'].astype(float, errors = 'raise')
ProjVsAct_df['OpponentPositionRank'] = ProjVsAct_df['OpponentPositionRank'].astype(float, errors = 'raise')
ProjVsAct_df.dtypes
# Out:
# Week                     object
# Name                     object
# ActFantasyPoints        float64
# PlayerID                 object
# Team                     object
# Position                 object
# PassingYards            float64
# Played                  float64
# PassingTouchdowns       float64
# PassingInterceptions    float64
# RushingTouchdowns       float64
# ReceivingYards          float64
# OpponentPositionRank    float64
# ProjFantasyPoints       float64
# dtype: object

# %%
 # Assign the data to X and y

X = ProjVsAct_df[["Played","ReceivingYards","OpponentPositionRank","ProjFantasyPoints"]]
y = ProjVsAct_df["ActFantasyPoints"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (1924, 4) (1924, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
 # Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
 # Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.31616663780391363
# Testing Score: 0.2796816824487587

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), y_train - model.predict(X_train), c="blue", label="Training Data")
plt.scatter(model.predict(X_test), y_test - model.predict(X_test), c="green", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Residual Plot')
